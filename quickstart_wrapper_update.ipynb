# %%
from pydynverse.wrap import wrap_expression, infer_trajectory, add_dimred, add_prior_information
from pydynverse.methods import ti_comp1, ti_slingshot, ti_monocle_ddrtree, ti_mst, ti_scuba, ti_angle, ti_grandprix, ti_paga
from pydynverse.plot import plot_dimred
from pydynverse.dimred import dimred_mds

from pydynverse import logger

logger.setLevel("DEBUG")

# %%
# 1. 准备数据(wrap)
# 运行R脚本获得数据，为R对象
import rpy2.robjects as ro
from pydynverse.util import rpy2_read # 导入对应的装饰器， 实现数据自动转换
r_script = """
library(dyno)
data("fibroblast_reprogramming_treutlein")
fibroblast_reprogramming_treutlein
"""
fibroblast_reprogramming_treutlein = ro.r(r_script)

# 封装数据
dataset = wrap_expression(
    counts=fibroblast_reprogramming_treutlein["counts"],
    expression=fibroblast_reprogramming_treutlein["expression"]
)
logger.info(f"AnnData dataset:\n{dataset}")
logger.info("Dataset loading finished")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 13
#       9 fibroblast_reprogramming_treutlein = ro.r(r_script)
#      11 # 封装数据
#      12 dataset = wrap_expression(
# ---> 13     counts=fibroblast_reprogramming_treutlein["counts"],
#      14     expression=fibroblast_reprogramming_treutlein["expression"]
#      15 )
#      16 logger.info(f"AnnData dataset:\n{dataset}")
#      17 logger.info("Dataset loading finished")
#
# File ~/.conda/envs/pydynverse/lib/python3.10/site-packages/rpy2/robjects/vectors.py:266, in Vector.__getitem__(self, i)
#     265 def __getitem__(self, i):
# --> 266     res = super().__getitem__(i)
#     268     if isinstance(res, Sexp):
#     269         res = conversion.rpy2py(res)
#
# File ~/.conda/envs/pydynverse/lib/python3.10/site-packages/rpy2/rinterface_lib/sexp.py:619, in SexpVector.__getitem__(self, i)
#     610     res = self.from_iterable(
#     611         [
#     612             self._R_VECTOR_ELT(
#    (...)
#     616         cast_value=lambda x: x
#     617     )
#     618 else:
# --> 619     raise TypeError(
#     620         'Indices must be integers or slices, not %s' % type(i))
#     621 return res
#
# TypeError: Indices must be integers or slices, not <class 'str'>

# %%
# 2. 选择方法(method), 目前stuba和grandprix有点问题
# methods_selected_list = [ti_comp1(), ti_slingshot(), ti_monocle_ddrtree(), ti_mst(), ti_scuba(), ti_angle(), ti_grandprix()]
# methods_selected_list = [ti_slingshot()]
# methods_selected = methods_selected_list[0]

# 字典方式调用，方便后续保存json文件
# 每类wrapper选择一种方法
method_type_dict = {
    # type2method
    "trajectory": {
        "name": "slingshot",  # 轨迹推断方法名称
        "function": ti_slingshot,  # 轨迹方法函数名，不直接调用
    },
    "linear_trajectory": {
        "name": "comp1",
        "function": ti_comp1,
    },
    "cycle": {
        "name": "angle",
        "function": ti_angle,
    },
    "end_state_probabilities": {
        "name": "grandprix",
        "function": ti_grandprix,
    },
    "cluster_graph": {
        "name": "scuba",
        "function": ti_scuba,
    },
    "dimred_projection": {
        "name": "mst",
        "function": ti_mst,
    },
    "cell_graph": {
        "name": "monocle_ddrtree",
        "function": ti_monocle_ddrtree,
    },
}

method_type = "linear_trajectory" # 此处选择方法的wrapper类型
methods_selected = method_type_dict[method_type]["function"]()

logger.info(f"Methods {methods_selected} selecting finished")
# Out:
#                         DEBUG    Docker image(dynverse/ti_comp1:v0.9.9.01) loaded
#                         INFO     Methods {'method': {'id': 'comp1', 'name': 'Component 1', 'source': 'offtheshelf',
#                                  'platform': 'R'}, 'wrapper': {'type': 'linear_trajectory', 'topology_inference':
#                                  'fixed', 'trajectory_types': 'linear', 'input_required': 'expression', 'inputs':
#                                  input_id  required        type
#                                  0  expression      True  expression
#                                  1      dimred     False   parameter
#                                  2        ndim     False   parameter
#                                  3   component     False   parameter}, 'container': {'url':
#                                  'https://github.com/dynverse/ti_comp1', 'docker': 'dynverse/ti_comp1'}, 'package':
#                                  None, 'manuscript': None, 'parameters':                   id
#                                  description  \
#                                  id
#                                  dimred        dimred  Which dimensionality reduction method to use.
#                                  ndim            ndim                                            NaN
#                                  component  component                                            NaN
#
#                                                  type default  \
#                                  id
#                                  dimred     character     pca
#                                  ndim         integer       2
#                                  component    integer       1
#
#                                                                                        values  \
#                                  id
#                                  dimred     [pca, mds, tsne, ica, lle, landmark_mds, mds_s...
#                                  ndim                                                     NaN
#                                  component                                                NaN
#
#                                                                             distribution
#                                  id
#                                  dimred                                              NaN
#                                  ndim       {'type': 'uniform', 'lower': 2, 'upper': 30}
#                                  component  {'type': 'uniform', 'lower': 1, 'upper': 10}  , 'run': {'backend':
#                                  'container', 'container_id': 'dynverse/ti_comp1:v0.9.9.01'}} selecting finished

# %%
# 3. 运行方法(wrap)
# add_prior_information(dataset, end_n=3)  # 运行grandprix需要的先验知识
model = infer_trajectory(dataset, methods_selected)
logger.info(f"Methods executing finished, model: {model}")

# # 保存Docker Output输出的json文件
# import json

# method_name = method_type_dict[method_type]["name"]
# json_filename = f"output/24.11.27-quick_docker_output_json/{method_type}_{method_name}.json"
# with open(json_filename, "w") as f:
#     json.dump(model.output_json, f)
# logger.info(f"Docker output json file({json_filename}) save")
# Out:
#                         DEBUG    Temp wd: /tmp/tmpyl_drx9d
#                         DEBUG    Save json successfully, path: /tmp/tmpyl_drx9d/input.json
#                         DEBUG    h52json script:
#                                  /home/huang/PyCode/scRNA/PyDynverse/PyDynverse/pydynverse/util/../rscript/docker_i
#                                  nput_json2h5.R
# [2024年12月02日 11时44分37秒] DEBUG    CompletedProcess(args=['/home/huang/PyCode/scRNA/PyDynverse/PyDynverse/pydyn
#                                        verse/util/../rscript/docker_input_json2h5.R', '--input_json_filename',
#                                        '/tmp/tmpyl_drx9d/input.json', '--input_h5_filename',
#                                        '/tmp/tmpyl_drx9d/input.h5'], returncode=0, stdout='[1] "json2h5
#                                        successful!"\n', stderr='')
#                         DEBUG    json2h5 successful!
#                         DEBUG    docker args: ['--dataset', '/ti/input.h5', '--output', '/ti/output.h5']
# [2024年12月02日 11时44分40秒] DEBUG    Docker Finish
#                         DEBUG
#                         DEBUG    h52json script:
#                                  /home/huang/PyCode/scRNA/PyDynverse/PyDynverse/pydynverse/util/../rscript/docker_o
#                                  utput_h52json.R
# [2024年12月02日 11时44分41秒] DEBUG    CompletedProcess(args=['/home/huang/PyCode/scRNA/PyDynverse/PyDynverse/pydyn
#                                        verse/util/../rscript/docker_output_h52json.R', '--output_h5_filename',
#                                        '/tmp/tmpyl_drx9d/output.h5', '--output_json_filename',
#                                        '/tmp/tmpyl_drx9d/output.json'], returncode=0, stdout='[1] "h52json
#                                        successful!"\n', stderr='')
#                         DEBUG    h52json successful!
#                         DEBUG    Save json successfully, path: /tmp/tmpyl_drx9d/output.json
#                         INFO     Methods executing finished, model:
#                                              id: ['20241202_034439__data_wrapper__VZ2PVm4qrl'],
#                                              trajectory_type: ['linear'],
#                                              attribute_list: dict_keys(['id', 'pseudotime', 'output_h5_filename',
#                                  'output_json_filename', 'cell_ids', 'cell_info', 'milestone_ids',
#                                  'milestone_network', 'divergence_regions', 'milestone_percentages',
#                                  'progressions', 'trajectory_type', 'directed', 'dimred', 'dimred_projected',
#                                  'dimred_milestones', 'dimred_segment_progressions', 'dimred_segment_points',
#                                  'timings', 'output_json', 'adata'])

# %%
# 4. 绘制轨迹(dimred+plot)
# model = add_dimred(model, dimred_mds,  expression_source=dataset["expression"])  # 提取降维结果, 直接从docker输出容器获得
plot_dimred(model, expression_source=dataset["expression"], grouping=list(fibroblast_reprogramming_treutlein["grouping"]))
logger.info("Result plotting finished")
# Out:
#                         INFO     Coloring by grouping
# WARNING: The following color value found in adata.uns['grouping_colors'] is not valid: 'd2_induced'. Default colors will be used instead.
#                         INFO     Result plotting finished
