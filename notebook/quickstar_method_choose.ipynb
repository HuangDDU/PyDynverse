# %%
import pydynverse as pdv

logger = pdv.logger
logger.setLevel("DEBUG")
# Out:
#   _____       _____
#  |  __ \     |  __ \
#  | |__) |   _| |  | |_   _ _ ____   _____ _ __ ___  ___
#  |  ___/ | | | |  | | | | | '_ \ \ / / _ \ '__/ __|/ _ \
#  | |   | |_| | |__| | |_| | | | \ V /  __/ |  \__ \  __/
#  |_|    \__, |_____/ \__, |_| |_|\_/ \___|_|  |___/\___|
#          __/ |        __/ |
#         |___/        |___/

# %%
# 1. 准备数据(wrap)
# 运行R脚本获得数据，为R对象
import rpy2.robjects as ro
from pydynverse.util import rpy2_read # 导入对应的装饰器， 实现数据自动转换
r_script = """
library(dyno)
data("fibroblast_reprogramming_treutlein")
fibroblast_reprogramming_treutlein
"""
fibroblast_reprogramming_treutlein = ro.r(r_script)

# 封装数据
dataset = pdv.wrap.wrap_expression(
    counts=fibroblast_reprogramming_treutlein["counts"],
    expression=fibroblast_reprogramming_treutlein["expression"]
)
logger.info(f"AnnData dataset:\n{dataset}")
logger.info("Dataset loading finished")
# Out:
# R[write to console]: 载入需要的程辑包：dynfeature
#
# R[write to console]: 载入需要的程辑包：dynguidelines
#
# R[write to console]: 载入需要的程辑包：dynmethods
#
# R[write to console]: 载入需要的程辑包：dynplot
#
# R[write to console]: 载入需要的程辑包：dynwrap
# [2024年12月25日 15时38分20秒] DEBUG    Dataset created: {'id': '20241225_153820__data_wrapper__GmY82AobPV',
#                                        'cell_ids': ['1_iN1_C01', '1_iN1_C02', '1_iN1_C03', '1_iN1_C04',
#                                        '1_iN1_C05', '1_iN1_C07', '1_iN1_C08', '1_iN1_C09', '1_iN1_C10',
#                                        '1_iN1_C11', '1_iN1_C12', '1_iN1_C13', '1_iN1_C14', '1_iN1_C15',
#                                        '1_iN1_C16', '1_iN1_C17', '1_iN1_C19', '1_iN1_C20', '1_iN1_C21',
#                                        '1_iN1_C22', '1_iN1_C23', '1_iN1_C25', '1_iN1_C26', '1_iN1_C27',
#                                        '1_iN1_C29', '1_iN1_C30', '1_iN1_C31', '1_iN1_C33', '1_iN1_C34',
#                                        '1_iN1_C35', '1_iN1_C36', '1_iN1_C37', '1_iN1_C38', '1_iN1_C40',
#                                        '1_iN1_C41', '1_iN1_C42', '1_iN1_C43', '1_iN1_C44', '1_iN1_C46',
#                                        '1_iN1_C47', '1_iN1_C48', '1_iN1_C49', '1_iN1_C51', '1_iN1_C52',
#                                        '1_iN1_C53', '1_iN1_C54', '1_iN1_C55', '1_iN1_C56', '1_iN1_C57',
#                                        '1_iN1_C58', '1_iN1_C60', '1_iN1_C61', '1_iN1_C62', '1_iN1_C64',
#                                        '1_iN1_C66', '1_iN1_C67', '1_iN1_C68', '1_iN1_C69', '1_iN1_C70',
#                                        '1_iN1_C71', '1_iN1_C72', '1_iN1_C73', '1_iN1_C74', '1_iN1_C75',
#                                        '1_iN1_C78', '1_iN1_C79', '1_iN1_C80', '1_iN1_C81', '1_iN1_C82',
#                                        '1_iN1_C83', '1_iN1_C84', '1_iN1_C85', '1_iN1_C87', '1_iN1_C88',
#                                        '1_iN1_C89', '1_iN1_C91', '1_iN1_C92', '1_iN1_C93', '1_iN1_C94',
#                                        '1_iN1_C95', '1_iN1_C96', '1_iN2_C02', '1_iN2_C05', '1_iN2_C07',
#                                        '1_iN2_C08', '1_iN2_C09', '1_iN2_C12', '1_iN2_C13', '1_iN2_C14',
#                                        '1_iN2_C15', '1_iN2_C16', '1_iN2_C17', '1_iN2_C18', '1_iN2_C19',
#                                        '1_iN2_C20', '1_iN2_C22', '1_iN2_C23', '1_iN2_C24', '1_iN2_C25',
#                                        '1_iN2_C26', '1_iN2_C27', '1_iN2_C28', '1_iN2_C29', '1_iN2_C30',
#                                        '1_iN2_C31', '1_iN2_C32', '1_iN2_C33', '1_iN2_C35', '1_iN2_C36',
#                                        '1_iN2_C37', '1_iN2_C38', '1_iN2_C39', '1_iN2_C40', '1_iN2_C41',
#                                        '1_iN2_C42', '1_iN2_C44', '1_iN2_C47', '1_iN2_C48', '1_iN2_C49',
#                                        '1_iN2_C50', '1_iN2_C51', '1_iN2_C53', '1_iN2_C55', '1_iN2_C56',
#                                        '1_iN2_C57', '1_iN2_C58', '1_iN2_C60', '1_iN2_C61', '1_iN2_C62',
#                                        '1_iN2_C64', '1_iN2_C65', '1_iN2_C66', '1_iN2_C67', '1_iN2_C68',
#                                        '1_iN2_C69', '1_iN2_C71', '1_iN2_C74', '1_iN2_C76', '1_iN2_C77',
#                                        '1_iN2_C79', '1_iN2_C80', '1_iN2_C81', '1_iN2_C82', '1_iN2_C83',
#                                        '1_iN2_C84', '1_iN2_C85', '1_iN2_C86', '1_iN2_C87', '1_iN2_C88',
#                                        '1_iN2_C89', '1_iN2_C90', '1_iN2_C92', '1_iN2_C96', '1_iN3_C01',
#                                        '1_iN3_C02', '1_iN3_C03', '1_iN3_C05', '1_iN3_C06', '1_iN3_C08',
#                                        '1_iN3_C09', '1_iN3_C10', '1_iN3_C11', '1_iN3_C12', '1_iN3_C13',
#                                        '1_iN3_C14', '1_iN3_C15', '1_iN3_C16', '1_iN3_C17', '1_iN3_C18',
#                                        '1_iN3_C19', '1_iN3_C22', '1_iN3_C23', '1_iN3_C24', '1_iN3_C25',
#                                        '1_iN3_C26', '1_iN3_C27', '1_iN3_C30', '1_iN3_C31', '1_iN3_C32',
#                                        '1_iN3_C35', '1_iN3_C36', '1_iN3_C37', '1_iN3_C38', '1_iN3_C39',
#                                        '1_iN3_C42', '1_iN3_C43', '1_iN3_C44', '1_iN3_C45', '1_iN3_C49',
#                                        '1_iN3_C50', '1_iN3_C51', '1_iN3_C52', '1_iN3_C53', '1_iN3_C54',
#                                        '1_iN3_C58', '1_iN3_C60', '1_iN3_C61', '1_iN3_C62', '1_iN3_C65',
#                                        '1_iN3_C66', '1_iN3_C67', '1_iN3_C68', '1_iN3_C69', '1_iN3_C76',
#                                        '1_iN3_C77', '1_iN3_C80', '1_iN3_C82', '1_iN3_C94', '1?ggL_iN4_C14',
#                                        '1?ggM_iN4_C11', '1DgL_iN4_C45', '1dQ_iN2_C95', '1ggL_iN4_C01',
#                                        '1ggL_iN4_C04', '1ggL_iN4_C15', '1ggL_iN4_C17', '1ggL_iN4_C18',
#                                        '1ggL_iN4_C19', '1ggL_iN4_C26', '1ggL_iN4_C29', '1ggL_iN4_C41',
#                                        '1ggL_iN4_C50', '1ggL_iN4_C61', '1ggL_iN4_C64', '1ggL_iN4_C70',
#                                        '1ggL_iN4_C77', '1ggL_iN4_C78', '1ggL_iN4_C82', '1ggL_iN4_C89',
#                                        '1ggL_iN4_C90', '1ggL_iN4_C94', '1ggM_iN4_C08', '1ggM_iN4_C12',
#                                        '1ggM_iN4_C28', '1ggM_iN4_C32', '1ggM_iN4_C38', '1ggM_iN4_C43',
#                                        '1ggM_iN4_C51', '1ggM_iN4_C65', '1ggM_iN4_C72', '1ggM_iN4_C76',
#                                        '1ggM_iN4_C83', '1ggM_iN4_C85', '1ggS_iN4_C10', '1ggS_iN4_C13',
#                                        '1ggS_iN4_C67', '1gL_iN4_C39', '701_502_1_MEF2_A1_C03',
#                                        '701_502_1gg_22d1_C25', '701_503_1_MEF2_B1_C09', '701_503_1wg_22d2_C09',
#                                        '701_505_1_MEF2_C1_C15', '701_506_1_MEF2_D1_C21', '701_507_1_MEF2_E1_C25',
#                                        '701_507_1gg_22d2_C25', '701_508_1_MEF2_F1_C31', '701_510_1_MEF2_G1_C37',
#                                        '701_510_1g_22d1_C37', '701_511_1_MEF2_H1_C43', '701_511_1n_22d2_C43',
#                                        '701_513_1_Ascl1_20d_F10_C84', '701_515_1_Ascl1_20d_B1_C09',
#                                        '701_517_1_Ascl1_20d_D1_C21', '701_521_1_Ascl1_20d_G1_C37',
#                                        '702_502_1_MEF2_A2_C02', '702_502_1g_22d2_C02', '702_503_1_MEF2_B2_C08',
#                                        '702_503_1n_22d2_C08', '702_505_1_MEF2_C2_C14', '702_506_1_MEF2_D2_C20',
#                                        '702_506_1g_22d1_C14', '702_507_1_MEF2_D9_C22', '702_507_1g_22d2_C26',
#                                        '702_508_1_MEF2_E9_C30', '702_508_1n_22d2_C32', '702_510_1_MEF2_G2_C38',
#                                        '702_511_1_MEF2_H2_C44', '702_511_1gg_22d1_C20',
#                                        '702_515_1_Ascl1_20d_E11_C77', '702_517_1_Ascl1_20d_G11_C89',
#                                        '702_518_1_Ascl1_20d_H11_C95', '702_522_1_Ascl1_20d_H10_C96',
#                                        '703_502_1_MEF2_A3_C01', '703_502_1g_22d2_C01', '703_503_1_MEF2_B3_C07',
#                                        '703_503_1g_22d2_C07', '703_505_1_MEF2_C3_C13', '703_506_1_MEF2_D3_C19',
#                                        '703_506_1g_22d1_C38', '703_507_1_MEF2_E3_C27', '703_507_1wg_22d1_C07',
#                                        '703_508_1_MEF2_F3_C33', '703_508_1gg_22d1_C13', '703_510_1_MEF2_B9_C10',
#                                        '703_510_1exclamationpoint_22d2_C39', '703_511_1_MEF2_H3_C45',
#                                        '703_511_1g_22d1_C19', '703_517_1_Ascl1_20d_D3_C19',
#                                        '703_520_1_Ascl1_20d_B12_C60', '703_522_1_Ascl1_20d_H12_C94',
#                                        '704_502_1_MEF2_A4_C49', '704_502_1wg_22d2_C49', '704_503_1gg_22d2_C55',
#                                        '704_505_1wg_22d2_C61', '704_506_1wg_22d2_C67', '704_507_1g_22d1_C39',
#                                        '704_513_1_Ascl1_20d_A4_C49', '704_515_1_Ascl1_20d_E12_C76',
#                                        '704_517_1_Ascl1_20d_D4_C67', '704_520_1_Ascl1_20d_F4_C81',
#                                        '704_521_1_Ascl1_20d_G4_C87', '705_502_1_MEF2_A5_C50',
#                                        '705_502_1gg_22d1_C56', '705_503_1_MEF2_B5_C56', '705_503_1gg_22d2_C56',
#                                        '705_505_1_MEF2_C5_C62', '705_506_1_MEF2_D5_C68', '705_506_1g_22d2_C68',
#                                        '705_507_1_MEF2_B11_C59', '705_507_1gg_22d2_C74', '705_508_1_MEF2_C11_C65',
#                                        '705_510_1_MEF2_D11_C71', '705_511_1_MEF2_E10_C78',
#                                        '705_513_1_Ascl1_20d_A5_C50', '705_515_1_Ascl1_20d_F12_C82',
#                                        '705_516_1_Ascl1_20d_C5_C62', '705_521_1_Ascl1_20d_D11_C71',
#                                        '706_502_1_MEF2_A6_C51', '706_502_1g_22d2_C51', '706_503_1_MEF2_B6_C57',
#                                        '706_503_1gg_22d2_C57', '706_505_1_MEF2_C6_C63', '706_505_1g_22d1_C80',
#                                        '706_506_1_MEF2_D6_C69', '706_506_1wg_22d2_C69', '706_507_1_MEF2_A12_C54',
#                                        '706_507_1g_22d2_C73', '706_508_1_MEF2_F6_C79', '706_508_1g_22d1_C73',
#                                        '706_510_1_MEF2_C12_C66', '706_510_1g_22d1_C85', '706_511_1_MEF2_E12_C76',
#                                        '706_511_1gg_22d1_C06', '706_513_1_Ascl1_20d_A6_C51',
#                                        '706_515_1_Ascl1_20d_B6_C57', '706_518_1_Ascl1_20d_C11_C65',
#                                        '706_520_1_Ascl1_20d_F6_C79', '706_521_1_Ascl1_20d_G6_C85',
#                                        '707_502_1_MEF2_A8_C05', '707_502_1g_22d1_C12', '707_503_1_MEF2_B8_C11',
#                                        '707_503_1g_22d1_C18', '707_505_1_MEF2_C8_C17', '707_506_1_MEF2_D8_C23',
#                                        '707_506_1g_22d2_C24', '707_507_1_MEF2_E8_C29', '707_507_1g_22d1_C28',
#                                        '707_508_1_MEF2_F8_C35', '707_510_1g_22d2_C40',
#                                        '707_511_1questionmarkgg_22d2_C46', '707_515_1_Ascl1_20d_B7_C12',
#                                        '707_520_1_Ascl1_20d_A10_C52', '707_521_1_Ascl1_20d_B10_C58',
#                                        '707_522_1_Ascl1_20d_C10_C64', '710_502_1bg_22d2_C05',
#                                        '710_505_1gposdquestionmark_22d2_C17', '710_506_1gg_22d1_C11',
#                                        '710_507_1wg_22d1_C23', '710_508_1g_22d1_C29', '710_510_1g_22d2_C41',
#                                        '711_502_1gg_22d1_C35', '711_503_1gg_22d2_C10', '711_505_1g_22d1_C47',
#                                        '711_506_1g_22d2_C22', '711_507_1gg_22d1_C16', '711_508_1gg_22d1_C36',
#                                        '711_510_1wg_22d2_C42', '711_511_1gg_22d1_C42', '712_502_1g_22d2_C52',
#                                        '712_503_1gg_22d2_C58', '712_505_1gg_22d1_C52', '712_506_1g_22d2_C70',
#                                        '712_507_1gquestionmark_22d2_C78', '712_508_1g_22d1_C71',
#                                        '714_503_1g_22d1_C83', '714_505_1wg_22d2_C65', '714_506_1g_22d1_C54',
#                                        '714_507_1g_22d1_C60', '714_508_1g_22d1_C72', '715_506_1gg_22d2_C72',
#                                        '715_507_1gg_22d2_C76', '715_508_1n_22d1_C70'], 'cell_info': Empty DataFrame
#                                        Columns: []
#                                        Index: [1_iN1_C01, 1_iN1_C02, 1_iN1_C03, 1_iN1_C04, 1_iN1_C05, 1_iN1_C07,
#                                        1_iN1_C08, 1_iN1_C09, 1_iN1_C10, 1_iN1_C11, 1_iN1_C12, 1_iN1_C13, 1_iN1_C14,
#                                        1_iN1_C15, 1_iN1_C16, 1_iN1_C17, 1_iN1_C19, 1_iN1_C20, 1_iN1_C21, 1_iN1_C22,
#                                        1_iN1_C23, 1_iN1_C25, 1_iN1_C26, 1_iN1_C27, 1_iN1_C29, 1_iN1_C30, 1_iN1_C31,
#                                        1_iN1_C33, 1_iN1_C34, 1_iN1_C35, 1_iN1_C36, 1_iN1_C37, 1_iN1_C38, 1_iN1_C40,
#                                        1_iN1_C41, 1_iN1_C42, 1_iN1_C43, 1_iN1_C44, 1_iN1_C46, 1_iN1_C47, 1_iN1_C48,
#                                        1_iN1_C49, 1_iN1_C51, 1_iN1_C52, 1_iN1_C53, 1_iN1_C54, 1_iN1_C55, 1_iN1_C56,
#                                        1_iN1_C57, 1_iN1_C58, 1_iN1_C60, 1_iN1_C61, 1_iN1_C62, 1_iN1_C64, 1_iN1_C66,
#                                        1_iN1_C67, 1_iN1_C68, 1_iN1_C69, 1_iN1_C70, 1_iN1_C71, 1_iN1_C72, 1_iN1_C73,
#                                        1_iN1_C74, 1_iN1_C75, 1_iN1_C78, 1_iN1_C79, 1_iN1_C80, 1_iN1_C81, 1_iN1_C82,
#                                        1_iN1_C83, 1_iN1_C84, 1_iN1_C85, 1_iN1_C87, 1_iN1_C88, 1_iN1_C89, 1_iN1_C91,
#                                        1_iN1_C92, 1_iN1_C93, 1_iN1_C94, 1_iN1_C95, 1_iN1_C96, 1_iN2_C02, 1_iN2_C05,
#                                        1_iN2_C07, 1_iN2_C08, 1_iN2_C09, 1_iN2_C12, 1_iN2_C13, 1_iN2_C14, 1_iN2_C15,
#                                        1_iN2_C16, 1_iN2_C17, 1_iN2_C18, 1_iN2_C19, 1_iN2_C20, 1_iN2_C22, 1_iN2_C23,
#                                        1_iN2_C24, 1_iN2_C25, 1_iN2_C26, ...]
#
#                                        [392 rows x 0 columns], 'feature_ids': ['Acta1', 'Tnnc2', 'Myl1', 'Tnni1',
#                                        'Tnnc1', 'Pgam2', 'S100a6', 'Acta2', 'Tnnt2', 'Mylpf', 'Tnnt3', 'Mgp',
#                                        'S100a4', 'Tagln', 'Spp1', 'Anxa1', 'Timp1', 'Cox8b', 'Cav1', 'Bgn',
#                                        'Arhgdib', 'Tagln2', 'Anxa2', 'Fstl1', 'Ifitm3', 'Tm4sf1', 'Snca', 'Eno3',
#                                        'Anxa3', 'Itm2a', 'Vim', 'Cox6a2', 'Crabp1', 'Gja1', 'Postn', 'Cnn2',
#                                        'Cdkn1c', 'Col1a2', 'Ifi27l2a', 'Tubb3', 'Fhl1', 'Tnfrsf12a', 'Itgb1bp2',
#                                        'Mfap2', 'Atp6v0c', 'Rrm2', 'Nupr1', 'Serpine2', 'S100a11', 'Fos', 'Ogn',
#                                        'Ascl1', 'Mybpc1', '1810020D17Rik', 'Tpm4', 'Gsto1', 'Ldb3', 'Ifitm2',
#                                        'Tnnt1', 'Serpinf1', 'Il1rl1', 'S100a10', 'Ndufs5', 'Cks1b', 'Prune2',
#                                        'Myl9', 'Mfap4', 'D0H4S114', 'Ddx39', 'Asph', 'Mest', 'Hspb8', 'Kbtbd10',
#                                        'Emp3', 'rtTA', 'Dcn', 'Pdlim3', 'Hmga2', 'Sc4mol', 'Enc1', 'Ppic', 'Sept4',
#                                        'Prss23', 'Prdx4', 'Sgk1', 'Egr1', 'Sdc4', 'Cd44', 'Lrrc17', 'Crip1', 'Mt1',
#                                        'Aspn', 'Timm10', 'Emp1', 'Hist1h2bc', 'Mgst1', 'Aprt', 'Fxyd1', 'Stmn1',
#                                        'Pmp22', 'Ppa1', 'Sdpr', 'Acot7', 'Cyb5', 'Thbs1', 'Hes6', 'Fkbp7',
#                                        '2700094K13Rik', 'Serpinb6a', 'Pdpn', 'Lpar1', 'Tspo', 'Klhl13', 'Ptp4a1',
#                                        'Sox11', 'Tipin', 'Ccdc80', 'Psat1', 'Ankrd1', 'Adm', 'Adk', 'Litaf',
#                                        'Asns', 'Tpm2', 'Ptrf', 'Ctsz', 'Cd24a', 'Mgst3', 'Birc5', 'Eif1a',
#                                        'Vkorc1', 'Bex1', 'Srpk3', 'Nmd3', 'Lxn', 'Vamp8', 'Timm8a1', 'Pgrmc1',
#                                        'Lsm3', 'A330076H08Rik', 'Scpep1', 'Tmem176b', 'Efemp2', 'Peg3as', 'Hat1',
#                                        'Pcolce', 'Ak1', 'Col3a1', 'Cyr61', 'Dcaf13', 'Cxcl12', 'Ifi27l1', 'Ldhb',
#                                        'Ddah1', '1700029F09Rik', 'Timp3', 'Eef1e1', 'Snhg1', '3110003A17Rik',
#                                        'Anxa4', 'Crabp2', 'D16H22S680E', 'Cd9', 'Ppap2a', 'Fam60a', 'Mt2', 'Crip2',
#                                        'Ccl7', 'EGFP', 'Mrps18b', 'Snhg3', 'Lox', 'Tmed3', 'Exosc8', 'Hmox1',
#                                        'Plin2', 'Rpl30', 'Pkia', 'Gcsh', 'Cyba', 'Pon3', 'Rhoc', 'Bre', 'Maged2',
#                                        'Hsdl1', 'Rars', 'Gpx8', 'Mospd1', 'Hspb6', 'Hsd17b12', 'Mtap', 'R3hdml',
#                                        'Ptn', 'Ncs1', 'Gstm5', 'Msn', 'Pttg1', 'Glrx', 'Lgals3', 'Id3', 'Fabp7',
#                                        '2010003O02Rik', 'Fabp5', 'Elovl1', 'Snrpd3', 'N6amt2', 'Tfpi', 'Hmgcs1',
#                                        'Mfge8', 'Pttg1ip', 'Aga', 'Hmga1-rs1', 'Ndufaf2', 'Naa38', 'Fbln2',
#                                        'Dnajc15', 'Kcne1l', 'D17Wsu104e', 'Rqcd1', 'Igfbp5', 'Hddc2', 'Pdzd11',
#                                        'Hagh', 'Mllt11', 'Fn1', 'Pdia6', 'Hmox2', 'Rnase4', 'Stt3a', 'Zfp57',
#                                        'Tspan6', 'Tspan12', 'Ube2c', 'Rcn3', 'Ephx1', 'Id2', 'Rab31', 'Gsta4',
#                                        'Snhg5', 'Ldha', 'Ech1', 'Ppil3', 'Dner', 'H19', 'Ypel3', 'Tubb4b',
#                                        'Chrac1', 'Praf2', 'Brcc3', 'Med21', 'Sparc', 'Ppp6c', 'Lyrm5', 'Penk',
#                                        'Magoh', 'AI413582', '1110038B12Rik', 'Meg3', 'Mb', 'Pdia4', 'Sec11c',
#                                        'Cthrc1', 'Uchl1', 'Sertad4', 'Mettl10', 'Polr2e', 'Oat', 'Emg1', 'Pfn2',
#                                        'Btg2', 'Tubb2a', 'Nop56', 'Nbl1', 'Pts', 'Dap', 'Gdpd1', 'Vamp3', 'Plp2',
#                                        'Pea15a', 'Gt(ROSA)26Sor', 'Cops5', '2410022L05Rik', 'Znhit3', 'Nsmce2',
#                                        'Wdr74', 'Ahsa1', 'Prmt2', 'Fam118b', '1110059E24Rik', '1110002B05Rik',
#                                        'Tubb6', 'Slc25a17', 'Ercc1', 'Tmem97', '1810013D10Rik', 'Spcs3', 'Nhp2',
#                                        'Aimp2', 'Ak2', 'Nup43', 'Psmg2', 'Tspan7', 'Eif2s3y', 'Cryab', 'Ap1s1',
#                                        'Psmd5', 'Cnpy4', 'Hpcal1', 'Commd4', 'Hrsp12', '9130023H24Rik', 'Alg14',
#                                        'Gm20300', 'Acaa2', 'Coq7', 'Siva1', 'Creb3', 'Mrps28', 'Acn9', 'Gadd45g',
#                                        'Nit2', 'Zfp386', 'Med27', 'Apool', 'Fam136a', 'Cdh13', 'Kars', 'Filip1l',
#                                        'Parm1', 'Oaz1-ps', 'Snap47', 'Fam195b', 'Golt1b', 'Memo1', 'Rgs19',
#                                        'Rdh13', 'Cd59a', 'Triap1', 'Col1a1', 'Gas2', 'Col8a1', 'Pmm1', 'Fam134b',
#                                        'Trp53', 'Dpm2', 'Snrpa1', 'Thyn1', 'Rnf13', 'Mcts1', 'Zfp948', 'Gm13363',
#                                        'Zfp637', 'Orc6', 'Pmpcb', 'Olfml3', 'Maf', 'Tmem60', '1700019E19Rik',
#                                        'Fkbp2', 'Nop16', 'Jagn1', 'Tmem98', 'Lass2', 'Prpf38a', 'Nubp2', 'Exosc7',
#                                        'Mrps6', 'Rnf181', 'AA465934', 'Pdgfrl', 'Cyb5r1', 'Lsm10', 'Copz1',
#                                        'Ssna1', 'Mrpl40', 'Ngdn', 'Zfp655', 'Mustn1', 'Nipsnap3b', 'Atp6v1b2',
#                                        'Pgcp', 'Hspb11', 'Clic1', 'Drg2', 'Fez1', 'Arl2', 'Rabggtb',
#                                        'A930003A15Rik', 'Zyx', 'Mmadhc', 'Shisa5', 'Ranbp1', 'Vps25', 'Rrm1',
#                                        'Trappc1', 'Isca2', 'Bag2', 'H2-D1', 'Snap25', 'Tomm5', 'Cox19', 'Bnip3',
#                                        'Tes', 'Rogdi', 'F3', 'Pmf1', 'Dhrs1', 'Ecscr', 'Ccs', 'Rbm18', 'Gtf2e2',
#                                        'Kpna2', 'Sccpdh', 'Arpc5', '0610007P14Rik', 'Ly6e', 'Fam96a', 'Agtr2',
#                                        'Churc1', 'Tmem176a', 'BC013529', 'Cops3', 'Rps4y2', 'Iah1', 'Hprt',
#                                        'Tmem119', 'Tbc1d7', 'Polb', 'Chchd3', 'Apip', '2310045N01Rik', 'Gyg',
#                                        'Ddah2', 'Hsd17b10', '2900064A13Rik', 'Prdx6', '1110012L19Rik', 'Dkc1',
#                                        'Stmn2', '2310009A05Rik', 'Dctn6', 'Apex1', 'Bet1', 'Cldn25', 'Commd10',
#                                        'Syngr2', 'Ict1', 'Ube2e3', 'Laptm4b', 'Trp53inp1', 'Stard3nl', 'Scnm1',
#                                        'Lgmn', 'Slc35a1', 'Ddit3', 'Nae1', 'Tspan14', 'G0s2', 'Pmm2', 'Mat2b',
#                                        'Mcfd2', 'Bccip', 'Adh5', 'Atp6v0c-ps2', 'Lamtor2', 'Rnf14', 'Farsa',
#                                        'Sec61a1', 'Ckb', 'Fam162a', 'Pdrg1', 'Snrpn', '5430417L22Rik', 'Fam18b',
#                                        'Nudcd2', 'Efna5', 'Bex2', 'Tm2d3', 'Hspa14', 'Sat1', 'Calu', 'Fundc1',
#                                        '1700021F05Rik', 'Tmx2', 'Pdcd6', 'Klf6', 'Aip', 'Sepp1', 'Ccdc53',
#                                        'Hist1h4d', 'Tmx1', 'Lum', 'Yif1b', 'Rpp30', 'C1qbp', 'Stx12', 'Pld3',
#                                        'Pa2g4', 'Herpud1', 'Dctpp1', '0610011F06Rik', 'C1galt1c1', 'Ppp2r2d',
#                                        'Magohb', 'Slc29a1', 'Grina', 'Gm561', 'Gstm1', 'Dnpep', 'Idh3b', 'Des',
#                                        'Polr2d', 'Ly6a', 'Ccndbp1', 'Chchd4', 'Tmem179b', '0610031J06Rik', 'Use1',
#                                        'Ndrg3', 'Cks2', 'Gtf2b', 'Gpn1', 'Plrg1', 'Bzw2', 'Araf', 'Eif2b1',
#                                        'Mterfd1', 'Tmem128', 'Hexa', 'Mrpl55', 'Ap1m1', 'Cib1', 'Mrpl47', 'Lbr',
#                                        'Fibin', 'Yipf1', 'Psmd10', 'Yif1a', 'Mrps18a', 'Capg', '2810025M15Rik',
#                                        'Atad1', '1110008P14Rik', 'Ccnd1', 'Mrpl2', 'Idi1', 'Med6', 'Commd9',
#                                        'Acot13', 'Nsmce1', 'Sgta', 'Gsn', 'Srsf7', 'Mrpl54', 'Erp29', 'Elovl5',
#                                        'Eif4ebp1', 'Tspan4', 'Ttc33', 'Id1', 'Txndc12', '2810008M24Rik', 'Stra13',
#                                        'Rab3a', 'Hnrnpa1', 'Haus1', 'Eri3', 'Tgif1', 'Slbp', 'Pvalb', 'Drg1',
#                                        'Tmem85', 'Uchl5', 'Ppie', 'Efemp1', 'Lhfp', 'Mettl11a', 'Coro1b',
#                                        'Tmem199', 'Tmem126b', 'Smarcb1', 'Rnh1', 'Dhrs3', 'Coq9', 'Pnrc2', 'Taf13',
#                                        'Igbp1', 'Ggh', 'Zc3h12c', 'Eif1b', 'Cops8', 'Dtymk', 'Rap1b', 'Dscr3',
#                                        'Rab9', 'Nudt16l1', 'Mrpl9', 'Snx2', 'Pls3', 'Ptpn2', 'Atp6ap2', 'Pno1',
#                                        'Gas1', 'Snx7', 'Exosc9', 'Vgll4', 'Gemin7', '1110001J03Rik', 'Pop7',
#                                        '2810422J05Rik', 'Ndn', 'Rpp21', 'Slc35b1', 'Glipr2', 'Slc25a11', 'Nxf1',
#                                        'Cse1l', 'Gm14005', 'M6pr', 'Amn1', 'Fam45a', 'Lage3', 'Tmem223', 'Gstz1',
#                                        'Ddx47', 'Serp1', 'Actl6a', 'Anxa5', 'Eif2b3', 'Trappc2', 'Ccng1', 'Taf12',
#                                        'Wrb', 'Snhg4', 'Tmbim4', 'Clpp', 'Nid1', 'Angptl2', 'Hiatl1', 'Sec22b',
#                                        'Pop4', 'Abcf2', 'Plk2', 'Pxmp3', 'Sdc2', 'Cnn3', 'Ninj1', 'Fh1', 'Ctps',
#                                        'Prelid1', 'Sssca1', 'Renbp', 'Ssr2', 'Sec13', 'Atat1', 'Crcp', 'Dazap2',
#                                        'Arhgap44', 'Ugcg', 'Stip1', 'Sertad1', 'Ppp4c', 'Map2k1', 'Olfml2b',
#                                        'Ndufa9', 'Carkd', 'Med4', 'Rexo2', 'Scamp4', 'Echs1', '1300002E11Rik',
#                                        'Rhobtb3', 'Alg3', '2010107H07Rik', 'Ndufv1', 'Clk4', 'Hint2', 'Inpp5f',
#                                        'Rbm7', 'Gnpda2', 'Leprot', 'D10Wsu52e', 'Sgce', 'Pdlim1', '1810030N24Rik',
#                                        'Txn2', 'Slc50a1', 'Gng10', 'Ywhah', 'Fam96b', 'Prr13', 'Pja1', 'Pfkm',
#                                        'Zcchc12', 'Cav2', 'Igf2', 'Degs1', 'Pigu', 'Mak16', 'Mrps12', 'Lsmd1',
#                                        'Map2k3', 'Zfand1', 'Phb2', 'Timm9', 'Tnni2', 'Ugdh', 'Coq10b', 'Paics',
#                                        'Fam50a', 'Lypla1', 'Stx7', 'Mn1', 'Cirh1a', 'Hadh', 'Abcg1', 'Ppt1',
#                                        'Akt2', 'Haus3', 'Tmem222', 'Pgam1', 'Rabif', 'Ccl2', 'Nop58', 'Vta1',
#                                        'Pkig', 'Acot9', 'Surf2', 'Tmem109', 'Mrpl12', 'Ruvbl2', 'Gnb5', 'Fxyd6',
#                                        'Cyc1', 'Rpf2', 'Arxes2', 'Cdh11', 'Cpsf3', 'Pycrl', 'Necap1', 'Schip1',
#                                        '1810009A15Rik', 'Npdc1', 'Polr2h', 'Ikbip', 'Gna11', 'Snx17', 'Gtl3',
#                                        'Tank', '1500003O03Rik', 'Rars2', 'Polr1c', 'Ebf1', 'Utp11l', 'Ccdc124',
#                                        'Mthfd2', 'Atf3', 'Sra1', 'Cstb', 'Vps28', 'Olfm1', 'Eci1', 'Eif1ax',
#                                        'Slc25a39', 'Tmem208', 'S100a16', 'Tmem11', 'Ppil1', 'Ghr', 'Akr1e1',
#                                        'Acyp1', 'Eif2s3x', 'Pdlim5', 'Mrpl32', 'H47', 'Atp6v1c1', 'Ifi30', 'Uba3',
#                                        'Mrps15', 'Gm11974', 'Mettl4', 'Sae1', 'Cxx1c', 'Uba2', 'Tmx4', 'Snapin',
#                                        'Nudt2', 'Impa1', 'Ankrd10', 'Snap23', 'Tmem205', 'Abcg2', 'Gm12191',
#                                        '1810055G02Rik', 'Zfp260', 'Cnot7', 'Rpain', 'Kbtbd5', 'Ankrd46', 'U2af1l4',
#                                        'Ado', '4833439L19Rik', 'Wisp1', 'Mrpl14', 'Elof1', 'Pigp', 'Znrd1',
#                                        'Psmg3', 'Anapc4', 'Fbxo6', 'Blvra', 'Fam89b', 'AI314976', 'Shisa2',
#                                        'Bcl2l1', 'Nagk', 'Sc5d', 'Dtd1', 'Trnt1', '0610009B22Rik', 'Ece2', 'Rnd3',
#                                        'Rai12', 'Hbp1', '0610010O12Rik', 'Dpm3', 'Ccdc90b', 'Cetn2', 'Tmem38a',
#                                        'Mrpl16', 'Rassf1', 'Micu1', 'Unc50', 'Seh1l', 'Mrpl37', 'Pqbp1', 'Mki67ip',
#                                        'Snx12', 'Polr2j', 'Rab34', 'Capn2', 'Gpx1', 'Trappc4', 'Rab7', 'Ndufs1',
#                                        'Pak1ip1', '1500012F01Rik', 'Tm2d2', 'Mrpl49', '1810013L24Rik', 'Tmem5',
#                                        'Guk1', 'Snapc5', 'Urod', 'Golga7', 'Gamt', 'Mrps9', 'Nt5c', 'Mcee',
#                                        'Tmbim1', '5033414D02Rik', 'Ptcd3', 'Ufd1l', 'Rbmxl1', 'Etfdh', 'Smap1',
#                                        'Asb8', 'Gnl3', 'Sfrp2', 'Mrpl13', 'Fxyd5', 'Arl8b', 'Tagap1', 'Chmp2b',
#                                        'Peg12', 'Lrrfip1', 'Qdpr', 'Fkbp9', 'Ak3', 'Eif2a', 'Lsp1', 'Acadvl',
#                                        '2210013O21Rik', 'Tmem50b', 'Bcap29', 'Blvrb', 'Abhd4', 'Diablo', 'Mcts2',
#                                        'Dctn3', 'Mcm4', 'Ccdc107', 'AI462493', 'St3gal5', 'Scamp1', 'Mrpl46',
#                                        'Rsl1d1', 'Rfc4', 'Cdk2ap2', 'Gm20199', 'Nif3l1', 'Snapc3', 'Ift74', 'Gdi1',
#                                        'Rabl5', 'Pigyl', 'Atp6ap1', 'Dclk1', 'Snx5', 'Ostf1', 'Fam92a', 'Alg5',
#                                        'Cgrrf1', 'Tmed1', 'Alkbh3', 'Gtpbp4', 'Tctex1d2', '1700034H14Rik',
#                                        'Ppapdc1b', 'Oxr1', 'Pcna', 'Fbln5', 'Pfkfb2', 'Ralb', 'Polr2f', 'Slmo2',
#                                        'Fhl2', 'Nob1', 'Ube2e1', 'Sdcbp', 'Nasp', 'Pdha1', 'Eif3d', 'Lrrc59',
#                                        'Mrps23', 'Ubl7', 'Zfp68', 'Rnf2', 'Ormdl1', 'Cs', '0610010K14Rik', 'Atf4',
#                                        'Mad2l1', 'Asf1b', '2810417H13Rik', 'Ttyh2', 'Blmh', 'Cnih', 'Cnot6l',
#                                        'Bola3', 'Vti1b', '1110008F13Rik', 'Tmpo', 'Tmem123', 'Dram2', 'Rtn1',
#                                        'Phgdh', 'Spag7', '1110007C09Rik', 'Adi1', 'Gemin6', 'Ndufa10', 'Nrbp1',
#                                        'Ccdc23', 'Acyp2', 'Cops7a', 'Syt11', 'Farsb', 'Mpp6', 'Eif3f', 'Parl',
#                                        'Rpn2', 'Surf1', 'Mmp2', 'P4hb', 'Rrp15', 'Suclg1', 'Nicn1', 'Ss18', 'Ilf2',
#                                        'Atp6v1h', 'Mfap5', 'Mrps27', 'Mzt1', 'Cdc26', 'Mphosph6', 'Naa20', 'Isca1',
#                                        'Med8', 'Ntan1', 'Rbbp9', 'Il11ra1', '1500011H22Rik', 'Bub3', 'Ufsp2',
#                                        'Arl4a', 'Ccnd3', 'Col5a2', 'Psmg1', 'Tmem9b', 'Marcks', 'Ttc1', 'Ndufaf1',
#                                        'Lcmt1', 'Ctnna1', 'Mt3', 'Eci2', 'Fam54b', 'Mpzl1', 'Ptcd2', 'Tex264',
#                                        '1810046J19Rik', 'Plaur', 'Zfp317', '5730494N06Rik', 'Eif3l', 'Ltv1',
#                                        'Znf512b', 'Tpm1', 'Vps26a', 'Scg5', 'Ubxn1', 'Tmem43', 'Sumo3', 'Mrps22',
#                                        'Fbxo3', '5730437N04Rik', 'Far1', 'Mdm2', 'Cpe', 'Rnf4', 'Tmem111',
#                                        'Mrps10', 'Ppm1k', 'Pdlim7', 'Jtb', 'F2r', 'Hdac3', 'Fdft1', 'Nkiras2',
#                                        'Bax', 'Ube2f', '9430016H08Rik', 'Nxt1', 'H2-Ke2', 'Nde1', 'Pitpnb',
#                                        'Sec11a', 'Gorasp2', 'Polr2g', 'Gba', 'Snhg6', 'Psmg4', 'Dek', 'Dusp1',
#                                        'Xpo1', 'Acd', 'Zfp36l2', 'Dnajb4', 'Nudt5', 'Ptpla', '2410006H16Rik',
#                                        'Nup88', 'Tmed2', 'Nrp1', 'Rfc3', 'Lias', 'Ptplad1', 'Idh3a', 'Nckap1',
#                                        'Anxa7', 'Mrps16', 'Col6a1', 'Hibch', 'Sh3bgrl', 'Rpl26', 'Qars', 'Kdelr3',
#                                        'Zdhhc4', 'Hnrnpf', 'Trappc2l', 'Snrnp25', 'l7Rn6', 'Smu1', 'BC024659',
#                                        'Pigx', 'Wls', 'Sar1b', 'Hmgcl', 'Mettl5', 'Tsta3', 'Txndc5', 'Dhrs7',
#                                        'Grsf1', '2210021J22Rik', 'Ugp2', 'Vps41', 'Smc4', 'Nexn', 'Gnai3', 'Large',
#                                        'Sun1', 'Fnta', 'Dpysl3', 'Pwp1', 'Chst2', 'Erdr1', 'Klf10', 'Cetn3',
#                                        'Ilkap', 'D930014E17Rik', 'Sin3b', 'Bpgm', '1110058L19Rik', 'Tbcb',
#                                        'Akr1b8', 'Wbp2', 'Dctn2', 'Dlst', 'Mrpl44', 'Ensa', 'Haus7', 'Sec61a2',
#                                        'Rabac1', 'Mob2', 'Inhba', 'Aamp', 'Swi5', 'Mef2a', 'Copb2', 'Ppp1r15a',
#                                        'Bud31', 'Cct6a', 'Cdkn1a', 'Chmp3', 'Katna1', 'Clptm1l', '2310004N24Rik',
#                                        'Slc25a12', 'Ppm1h', 'Brd7', 'Rpa3', 'Itpripl1', 'Capns1', 'Zfp617',
#                                        'Nfe2l2', 'Lrpap1', 'Sf3b5', 'Mrpl36', 'Serping1', 'March2',
#                                        '3230401D17Rik', 'Tspan31', 'Copz2', 'Aarsd1', 'Ncbp2', 'Mrps7', 'Eif6',
#                                        'Idh2', 'Arl3', 'Apoa1bp', 'Sf3a3', 'Rbmx', 'Sypl', 'Polr1d', 'Dars',
#                                        'Phldb2', '0610037P05Rik', 'Tmod1', 'Yipf5', 'Arpc5l', 'Arl6ip5', 'Cept1',
#                                        'Tmem219', 'Trappc6b', 'Lta4h', 'Serf1', 'Pepd', 'Ppp2ca', 'Tmod3', 'Blcap',
#                                        'A430005L14Rik', 'Cat', 'Snx1', 'Stub1', '1810043H04Rik', 'Ndufs2', 'Hk2',
#                                        'Cyhr1', '1500015O10Rik', 'Tbrg1', 'Tmem68', 'Fam173a', 'Pmvk', 'Pnkd',
#                                        'Pole3', '0610007C21Rik', 'Prkcdbp', 'Nanp', 'Ddt', 'Tmem14c', 'Snx10',
#                                        'Mpv17', '2810002N01Rik', 'Elp2', 'Brix1', 'Bola2', 'Tubg1', 'Cript',
#                                        'Mocs2', 'Fam103a1', 'Erp44', 'Ift20', 'Exosc2', 'Mrpl27', 'Marcksl1',
#                                        'Hexb', 'Bnip2', 'Commd1', 'Cdkn2d', 'Mtx2', 'Gars', 'Phf5a', 'Mdp1',
#                                        'Nup37', 'Gtf3c6', '2810432D09Rik', 'Jam3', 'Cnot2', 'Tmed4', 'Tsnax',
#                                        'Apoe', 'Eif5a', 'Rtcd1', 'Eif3g', 'Anapc5', 'Ift27', 'Faim',
#                                        '2400003C14Rik', 'Ccdc109a', 'Usp14', 'Smndc1', 'Zwint', '2700007P21Rik',
#                                        'Timm50', 'Ndufs7', 'Yars', 'Atg12', 'Mrpl50', '5930416I19Rik', 'Trnp1',
#                                        'Wdr33', 'Abhd11', 'BC003266', 'Hsd17b4', 'Ap2s1', 'Slc35a4', 'Prkag1',
#                                        'Phpt1', 'Mrpl4', 'Srm', 'Wisp2', 'Mrpl34', 'Zmat5', 'Pcmt1', 'Cbr1',
#                                        'Rsu1', 'Sirt2', 'Fgf7', 'Armcx3', 'Ddx1', 'Kif2a', 'Maf1', 'Ctsk', 'Itpa',
#                                        'Mfsd1', 'Fkbp11', 'Zfp932', 'Actn1', 'Wdr61', 'Tacc3', 'Glod4', 'Surf4',
#                                        'Nup85', 'Nfkbia', 'Rab8a', 'Cdr2l', 'Rfc2', 'Ssrp1', 'Med10', 'Dnajb11',
#                                        'Cirbp', 'Txndc15', 'Mrps11', 'Lass5', 'Dnajc9', 'Cdk4', 'Tfrc', 'Foxn3',
#                                        'Grn', 'Ing4', 'Ndufaf3', 'Smarca2', 'Becn1', 'Cyp20a1', 'Fdx1l', 'Xpnpep1',
#                                        'Tsc22d1', 'Ddx39b', 'Dnttip2', 'Mrpl39', 'Caml', 'Cast', 'Rnf11', 'Aup1',
#                                        'Gtf2h2', '1110057K04Rik', '2810428I15Rik', 'Mrpl24', 'Mrpl28', 'Fcf1',
#                                        'Hibadh', 'Rab4a', 'Scamp3', 'Kctd10', 'Ndfip1', 'Gtf2f2', 'Chmp1a',
#                                        'Gulp1', 'Mrps35', 'Insig2', 'Syf2', 'Tmed5', 'Klhl22', 'Tmem120a', 'Asb5',
#                                        'Ostm1', 'Pon2', '1700113I22Rik', 'Wdr45l', 'Cmc1', 'B3galnt1', 'Cmtm3',
#                                        'Tmeff1', 'Lsm2', 'Tars', '9430023L20Rik', 'Dguok', 'Cryzl1', 'Slc3a2',
#                                        'Slc39a6', 'Arpc1a', 'Cav3', 'Birc2', 'Dnajc7', 'Oxct1', 'Mxra8', 'Mff',
#                                        'Mrpl53', 'Lonp2', 'Jkamp', 'Thumpd3', 'Idh3g', 'Tnfaip1', 'Dld', 'Prdx3',
#                                        'Etfb', 'Scfd1', 'Ift46', 'Cbr4', 'Cr1l', '4930453N24Rik', 'Cdadc1',
#                                        'Lrrc42', 'Eda2r', 'Fam107b', 'Ftsj3', 'Uros', 'Chchd1', 'Rab28',
#                                        '1700123O20Rik', 'Msto1', 'Frg1', 'Pygm', 'Acadm', 'Prmt7', 'Dhx15',
#                                        'Tsc22d3', 'Igf1', 'Poglut1', 'Rhog', '1500011B03Rik', 'Cited2', 'Klhl7',
#                                        'Nadk', 'Actr1a', 'Ap3s1', 'Hspd1', 'Chn2', 'Rhoq', 'Wdr37', 'Ssr4',
#                                        'Atp6v0e2', 'Otud6b', 'Gpx7', 'Gss', 'Cuedc2', 'Ddost', 'Adsl', 'Zfyve21',
#                                        'Ppil4', 'Imp4', 'Vipar', 'Tor1b', 'Pmpca', 'Nsdhl', 'Orc4', 'Bid',
#                                        'Tomm70a', 'Dpy30', 'Mrpl10', 'Gap43', 'Cops4', 'Hars', 'Fam33a', 'Pgls',
#                                        'Ccdc101', 'Tcta', 'Wdr77', '8430410K20Rik', 'Cd47', 'Stoml2', 'Rab30',
#                                        'Fibp', 'Tmem29', 'Tmem66', 'Tpd52', 'Cog4', '1500001M20Rik', 'Cmpk1',
#                                        'Tusc3', 'Acadsb', 'Ppp2cb', 'Rnf114', 'Fam192a', 'Ncald', 'Tgfb3',
#                                        'Ccrn4l', 'Ggps1', 'Mrpl1', 'Abhd14a', 'Gnptg', 'Nqo1', 'Cdca3', 'Flot1',
#                                        'Tpm3', 'Ly96', 'Prrx1', 'Taf11', 'Arfip1', 'Cuta', 'Wdr75', 'Mbnl1',
#                                        'Copg', 'Pgm2', 'Vbp1', 'Sbds', 'Arl1', 'Mtfr1', 'Errfi1', 'Psmc4', 'Cdc16',
#                                        'Got2', 'Sar1a', 'Psmd14', 'Zfp238', 'Trap1', 'Casp6', 'Rad21', 'Tcf12',
#                                        'Exosc1', 'Ccdc58', 'Nudt8', 'Coro1c', 'Snai2', 'Fbxo11', '2610524H06Rik',
#                                        'Hdac2', 'Adprh', 'Tomm22', 'Comt', 'Lap3', 'Cstf3', 'Ddrgk1', 'Mrpl43',
#                                        'Lsm4', 'Lyrm2', 'Tmem106c', 'Pigf', 'Snhg9', 'Loxl1', '9530068E07Rik',
#                                        'Psme1', 'Cab39', '2610301B20Rik', 'D230037D09Rik', 'Mgrn1', 'Uckl1',
#                                        'Prkra', 'C330007P06Rik', 'S100a13', 'Rchy1', 'Gpm6b', 'Sdf2', 'Cinp',
#                                        'Bag1', 'Fam164a', 'Eno1', 'Arl6ip1', 'Amd2', '1110051M20Rik', 'Snx4',
#                                        'Tpp1', 'Cacna2d1', 'Sgcb', 'Tmem184c', 'Gm5506', 'Rbms1', 'Rtn3', 'Ddx52',
#                                        'Ppp2r1a', 'Gnpnat1', 'Fkbp4', 'Nucb1', 'Creld2', 'Ostc', 'Yaf2', 'Ccdc104',
#                                        'Adam9', 'Cdk1', 'Rhoj', 'Actg2', 'Acat1', 'Zfp330', 'Efnb2', 'Atic',
#                                        'Clybl', 'Rad23a', '6330578E17Rik', 'Skap2', '4921524J17Rik', 'Psmc5',
#                                        'Gpc3', 'Sqstm1', 'Cnot8', 'Abce1', 'Itgb1bp1', 'Gpc4', 'Pdgfa', 'Arhgdia',
#                                        'Chchd7', 'Metap1', 'Casp3', 'Mbnl3', 'B230118H07Rik', 'Rpn1', 'Map1lc3a',
#                                        'Snapc2', 'Zbtb8os', 'Prc1', 'Zfp672', 'Commd5', 'Cd99l2', 'Ube2g2',
#                                        'Ndrg4', 'Uqcrc1', 'Sri', 'Adss', 'Crbn', 'Mier3', 'Eif2b2', 'Kdelc1',
#                                        '9130401M01Rik', 'Zfp277', '2210403K04Rik', 'Lyrm4', 'AI987944', 'Rpf1',
#                                        'Slc18a2', 'Rnf5', 'Grb10', 'Ngfrap1', 'Dctn5', 'Bag5', 'Dusp14',
#                                        'AW209491', 'Serinc2', 'Eif3j', 'Ccnh', 'Bfar', 'Gng11', 'Tmem170b',
#                                        'Chordc1', 'Sh3glb2', 'Serpine1', 'Selm', 'Maea', 'Flna', 'Zc3h14',
#                                        'Cacybp', 'Gfm1', 'Zfp62', 'Eapp', 'Zfp207', 'Stard7', 'D19Bwg1357e',
#                                        'Mrps2', 'Nip7', 'Atp6v0d1', 'Scrn1', 'Slc31a1', 'Tnfrsf1a', 'Gins4',
#                                        'Lima1', 'Kdm1b', 'Mtpap', 'Cisd1', 'Cdc123', 'Mrps34', 'Strap', 'Eif3b',
#                                        'Spc25', 'Ccnc', '1110002N22Rik', 'Eif2d', '1700020I14Rik', 'Ckap4',
#                                        'Aimp1', 'Xbp1', 'Pfdn4', 'Mmp14', 'Alg11', 'Ptbp2', 'Aktip', 'Rpl7l1',
#                                        'Ube2w', 'Asnsd1', 'Dnm3os', 'Sep15', 'Zfp36l1', 'Lamp2', 'Wdr43', 'Crot',
#                                        'Ctsd', 'Zcchc10', 'Smcr7l', 'Pfdn2', 'Ssu72', 'Ppap2b', '2010320M18Rik',
#                                        'Taf1d', 'Ubl4', 'Sox9', 'AI597468', 'Ergic3', 'Srprb', 'Got1', 'Snupn',
#                                        '2310046O06Rik', '1110034B05Rik', 'Ccdc47', 'Rrp1', 'Psmd8', 'Eps15',
#                                        'Nup93', 'Fam171b', 'Slc12a6', 'Cdipt', 'Tbce', 'Anxa6', 'Tceb3', 'Msra',
#                                        'Zfp266', 'Tram1', 'Arcn1', 'Kif20a', 'Pitrm1', 'Hnrnph1', 'Mrpl48', 'Abi2',
#                                        'B4galt1', 'Naa10', 'Ppme1', 'Tbx15', 'Fam114a2', 'Clk3', 'Acot10',
#                                        'Lamtor3', 'Wbp1', 'Cnpy2', 'Cyb5r3', '4732418C07Rik', 'Ppp2r3c', 'Coq5',
#                                        'Nat15', 'Lmcd1', 'Lgals8', 'Ptpmt1', 'Obfc2b', 'Ttc4', 'Tor1aip2', 'Fech',
#                                        'Dmtf1', 'Casc4', 'Tprgl', 'Ppil2', 'Sdha', 'Ncstn', '2610203C20Rik', 'Hn1',
#                                        'Dnajc30', 'Atg5', 'Mtap6', 'Ppfibp1', 'Bet1l', '2510006D16Rik', 'Clta',
#                                        'Gtf2f1', 'Sugt1', 'Ddx3y', 'Polr2i', 'Fbxo32', 'Idh1', 'Hspa13', 'Fez2',
#                                        'Tada1', 'Eif3i', 'Tfg', 'Glud1', '2410001C21Rik', 'Hmgn2', 'Ccdc25',
#                                        'Pdhb', 'Polr3k', 'Gng12', 'Stk17b', 'Ptgr1', 'Apoo', 'Dnajc4', 'Arf2',
#                                        '3110001D03Rik', 'Mrto4', 'Mea1', 'Actr1b', 'Eif4b', 'Ociad1', 'Mapk1ip1',
#                                        'Eid1', 'Gosr2', 'Srsf1', 'Fam198b', 'Parp2', 'Mtg1', 'Cdc42ep3', 'Slc20a1',
#                                        'Nck1', 'Klhdc2', '1110003E01Rik', 'Hbegf', 'Eif4e2', 'Hipk3', 'Vps29',
#                                        'Mkx', 'Sfxn1', 'Ccdc56', 'Gm5617', 'Avpi1', 'Trp53inp2', 'Slc38a2', 'Pigs',
#                                        'Mtap2', 'Hmgn1', '2310040G24Rik', 'Zfp639', 'Snrpd1', 'Chchd6', 'Serpinh1',
#                                        'Golph3', 'Armc1', 'Vps36', 'Tmem159', '1810030O07Rik', 'Thoc1', 'Dhrs7b',
#                                        'Ublcp1', 'Rps27', 'Arl5a', 'Mier1', 'Atp1b3', 'Cct3', 'Ifrd1', 'Gse1',
#                                        'Ube2a', 'Pla2g4a', 'Tgfb1i1', 'Cdk5', 'Kbtbd2', 'Dpcd', 'Socs2',
#                                        '3110040N11Rik', 'Impact', 'Cdc23', 'Llph', 'Pdcl', 'Nptn', 'Wdr6', 'Vcl',
#                                        'Lsg1', 'Cpsf3l', 'Cdc42se1', 'Srp68', 'Gde1', 'Stk3', 'Gnl2', 'Cct4',
#                                        'Ranbp9', 'Ccdc127', 'Tm9sf2', 'Timm17b', 'Pkp4', 'Asl', 'Slc31a2',
#                                        'D4Bwg0951e', '5730403B10Rik', 'Med7', 'Abi1', 'AK010878', 'Utp3', 'Rnps1',
#                                        'Otud1', 'Nenf', 'Btbd10', 'Aasdhppt', 'Fam58b', 'Gm2382', 'Fam32a',
#                                        '1700037H04Rik', 'Tmem70', 'Puf60', 'Clip3', 'Exoc7', 'Acat2', 'Cope',
#                                        'Ppp2r3a', 'Hsph1', 'Sec23b', 'Mycbp', 'Actr3', 'Api5', 'Bphl', 'Ola1',
#                                        'Zcchc9', 'Rcn2', 'Atg10', 'Ebna1bp2', 'Orc5', 'Npc2', 'Cd82', 'Krcc1',
#                                        'Pole4', 'Pdk3', 'Fbxo25', 'Mtx1', 'Sigmar1', 'Jag1', 'Sh3gl1', 'Rbbp7',
#                                        'Tceal7', 'Slc30a6', 'Alkbh8', 'Mrps17', '4933433P14Rik', 'Rab2b', 'Ube2l6',
#                                        'Gprasp1', 'Filip1', 'Bola1', 'Nucb2', 'Clu', 'Riok2', 'Enoph1', 'Hdhd2',
#                                        'Lman1', 'Zfp868', 'Airn', 'Ccnb1', 'Commd6', 'Nmt1', 'Rnf187', 'Gmpr',
#                                        'Stx5a', 'Fkbp8', 'Htatsf1', 'Brms1l', 'Bckdk', 'Dpy19l1', 'Flot2',
#                                        'Txnl4b', 'Mrpl3', 'Mlf2', 'Gatc', 'Zc3hc1', 'Mad2l2', 'Eif1ad', 'Mrpl18',
#                                        'Ivns1abp', 'Atoh8', 'Eed', 'Fbxo22', 'P4ha1', 'App', 'Tuba4a', 'Osbpl1a',
#                                        '1110065P20Rik', 'Palmd', 'Dnajc10', 'Snrpb2', 'Pstk', 'Aco2', 'Sqle',
#                                        'Ube2e2', 'Bod1', 'Ccpg1', 'Gpatch4', 'Chmp1b', 'Snx32', 'Polr2m', 'Trim35',
#                                        '2310004I24Rik', 'Tcp11l2', 'Fermt2', 'Ilf3', 'Brms1', 'Tmem218',
#                                        'Cdc42se2', 'Pih1d1', 'Syt4', 'Rapgef2', 'Wsb2', 'Tbc1d15', 'Las1l',
#                                        'Plekhb2', 'Prps1', 'Fabp3', 'Mrpl22', 'Kpna3', 'Mtch1', 'Wwtr1', 'Sec23a',
#                                        'Med31', 'Bhlhb9', '4933421E11Rik', 'Tmed7', 'Imp3', 'Lrrc28', 'Vps4a',
#                                        'Pgam5', 'Inpp4a', 'Pofut2', 'Mphosph10', 'Ctgf', '8430410A17Rik', 'Ppdpf',
#                                        'Cklf', 'Ifngr1', 'Anp32b', 'Akirin2', 'Hadhb', 'Wsb1', 'Tax1bp3', 'Tob1',
#                                        'Ttc35', 'Mapk3', 'Ccdc6', 'Zcchc18', 'Cstf1', 'Ccm2', 'Phax', 'Bin3',
#                                        'Arl6', 'Stmn3', 'Fam114a1', 'Vamp7', 'Zfp422', 'Ctsa', 'Lyar', 'Pdcl3',
#                                        'Bloc1s2', 'Tmem30a', 'Hmgb3'], 'feature_info': Empty DataFrame
#                                        Columns: []
#                                        Index: [Acta1, Tnnc2, Myl1, Tnni1, Tnnc1, Pgam2, S100a6, Acta2, Tnnt2,
#                                        Mylpf, Tnnt3, Mgp, S100a4, Tagln, Spp1, Anxa1, Timp1, Cox8b, Cav1, Bgn,
#                                        Arhgdib, Tagln2, Anxa2, Fstl1, Ifitm3, Tm4sf1, Snca, Eno3, Anxa3, Itm2a,
#                                        Vim, Cox6a2, Crabp1, Gja1, Postn, Cnn2, Cdkn1c, Col1a2, Ifi27l2a, Tubb3,
#                                        Fhl1, Tnfrsf12a, Itgb1bp2, Mfap2, Atp6v0c, Rrm2, Nupr1, Serpine2, S100a11,
#                                        Fos, Ogn, Ascl1, Mybpc1, 1810020D17Rik, Tpm4, Gsto1, Ldb3, Ifitm2, Tnnt1,
#                                        Serpinf1, Il1rl1, S100a10, Ndufs5, Cks1b, Prune2, Myl9, Mfap4, D0H4S114,
#                                        Ddx39, Asph, Mest, Hspb8, Kbtbd10, Emp3, rtTA, Dcn, Pdlim3, Hmga2, Sc4mol,
#                                        Enc1, Ppic, Sept4, Prss23, Prdx4, Sgk1, Egr1, Sdc4, Cd44, Lrrc17, Crip1,
#                                        Mt1, Aspn, Timm10, Emp1, Hist1h2bc, Mgst1, Aprt, Fxyd1, Stmn1, Pmp22, ...]
#
#                                        [2000 rows x 0 columns], 'pydynwrap:data_wrapper': True}
#                         DEBUG    Andata counts and expression added
#                         INFO     AnnData dataset:
#                                  {'id': '20241225_153820__data_wrapper__GmY82AobPV', 'cell_ids': ['1_iN1_C01',
#                                  '1_iN1_C02', '1_iN1_C03', '1_iN1_C04', '1_iN1_C05', '1_iN1_C07', '1_iN1_C08',
#                                  '1_iN1_C09', '1_iN1_C10', '1_iN1_C11', '1_iN1_C12', '1_iN1_C13', '1_iN1_C14',
# ...
#                                  'Dnajb4', 'Nudt5', 'Ptpla', '2410006H16Rik', 'Nup88', 'Tmed2', 'Nrp1', 'Rfc3',
#                                  'Lias', 'Ptplad1', 'Idh3a', 'Nckap1', 'Anxa7', 'Mrps16', 'Col6a1', 'Hibch',
#                                  'Sh3bgrl', 'Rpl26', 'Qars', 'Kdelr3', 'Zdhhc4', 'Hnrnpf', 'Trappc2l', 'Snrnp25',
#                                  'l7Rn6', 'Smu1', 'BC024659', 'Pigx', 'Wls', 'Sar1b', 'Hmgcl', 'Mettl5', 'Tsta3',
#                                  'Txndc5', 'Dhrs7', 'Grsf1', '2210021J22Rik', 'Ugp2', 'Vps41', 'Smc4', 'Nexn',
#                                  'Gnai3', 'Large', 'Sun1', 'Fnta', 'Dpysl3', 'Pwp1', 'Chst2', 'Erdr1', 'Klf10',
#                                  'Cetn3', 'Ilkap', 'D930014E17Rik', 'Sin3b', 'Bpgm', '1110058L19Rik', 'Tbcb',
#                                  'Akr1b8', 'Wbp2', 'Dctn2', 'Dlst', 'Mrpl44', 'Ensa', 'Haus7', 'Sec61a2', 'Rabac1',
#                                  'Mob2', 'Inhba', 'Aamp', 'Swi5', 'Mef2a', 'Copb2', 'Ppp1r15a', 'Bud31', 'Cct6a',
#                                  'Cdkn1a', 'Chmp3', 'Katna1', 'Clptm1l', '2310004N24Rik', 'Slc25a12', 'Ppm1h',
#                                  'Brd7', 'Rpa3', 'Itpripl1', 'Capns1', 'Zfp617', 'Nfe2l2', 'Lrpap1', 'Sf3b5',
#                                  'Mrpl36', 'Serping1', 'March2', '3230401D17Rik', 'Tspan31', 'Copz2', 'Aarsd1',
#                                  'Ncbp2', 'Mrps7', 'Eif6', 'Idh2', 'Arl3', 'Apoa1bp', 'Sf3a3', 'Rbmx', 'Sypl',
#                                  'Polr1d', 'Dars', 'Phldb2', '0610037P05Rik', 'Tmod1', 'Yipf5', 'Arpc5l',
#                                  'Arl6ip5', 'Cept1', 'Tmem219', 'Trappc6b', 'Lta4h', 'Serf1', 'Pepd', 'Ppp2ca',
#                                  'Tmod3', 'Blcap', 'A430005L14Rik', 'Cat', 'Snx1', 'Stub1', '1810043H04Rik',
#                                  'Ndufs2', 'Hk2', 'Cyhr1', '1500015O10Rik', 'Tbrg1', 'Tmem68', 'Fam173a', 'Pmvk',
#                                  'Pnkd', 'Pole3', '0610007C21Rik', 'Prkcdbp', 'Nanp', 'Ddt', 'Tmem14c', 'Snx10',
#                                  'Mpv17', '2810002N01Rik', 'Elp2', 'Brix1', 'Bola2', 'Tubg1', 'Cript', 'Mocs2',
#                                  'Fam103a1', 'Erp44', 'Ift20', 'Exosc2', 'Mrpl27', 'Marcksl1', 'Hexb', 'Bnip2',
#                                  'Commd1', 'Cdkn2d', 'Mtx2', 'Gars', 'Phf5a', 'Mdp1', 'Nup37', 'Gtf3c6',
#                                  '2810432D09Rik', 'Jam3', 'Cnot2', 'Tmed4', 'Tsnax', 'Apoe', 'Eif5a', 'Rtcd1',
#                                  'Eif3g', 'Anapc5', 'Ift27', 'Faim', '2400003C14Rik', 'Ccdc109a', 'Usp14',
#                                  'Smndc1', 'Zwint', '2700007P21Rik', 'Timm50', 'Ndufs7', 'Yars', 'Atg12', 'Mrpl50',
#                                  '5930416I19Rik', 'Trnp1', 'Wdr33', 'Abhd11', 'BC003266', 'Hsd17b4', 'Ap2s1',
#                                  'Slc35a4', 'Prkag1', 'Phpt1', 'Mrpl4', 'Srm', 'Wisp2', 'Mrpl34', 'Zmat5', 'Pcmt1',
#                                  'Cbr1', 'Rsu1', 'Sirt2', 'Fgf7', 'Armcx3', 'Ddx1', 'Kif2a', 'Maf1', 'Ctsk',
#                                  'Itpa', 'Mfsd1', 'Fkbp11', 'Zfp932', 'Actn1', 'Wdr61', 'Tacc3', 'Glod4', 'Surf4',
#                                  'Nup85', 'Nfkbia', 'Rab8a', 'Cdr2l', 'Rfc2', 'Ssrp1', 'Med10', 'Dnajb11', 'Cirbp',
#                                  'Txndc15', 'Mrps11', 'Lass5', 'Dnajc9', 'Cdk4', 'Tfrc', 'Foxn3', 'Grn', 'Ing4',
#                                  'Ndufaf3', 'Smarca2', 'Becn1', 'Cyp20a1', 'Fdx1l', 'Xpnpep1', 'Tsc22d1', 'Ddx39b',
#                                  'Dnttip2', 'Mrpl39', 'Caml', 'Cast', 'Rnf11', 'Aup1', 'Gtf2h2', '1110057K04Rik',
#                                  '2810428I15Rik', 'Mrpl24', 'Mrpl28', 'Fcf1', 'Hibadh', 'Rab4a', 'Scamp3',
#                                  'Kctd10', 'Ndfip1', 'Gtf2f2', 'Chmp1a', 'Gulp1', 'Mrps35', 'Insig2', 'Syf2',
#                                  'Tmed5', 'Klhl22', 'Tmem120a', 'Asb5', 'Ostm1', 'Pon2', '1700113I22Rik', 'Wdr45l',
#                                  'Cmc1', 'B3galnt1', 'Cmtm3', 'Tmeff1', 'Lsm2', 'Tars', '9430023L20Rik', 'Dguok',
#                                  'Cryzl1', 'Slc3a2', 'Slc39a6', 'Arpc1a', 'Cav3', 'Birc2', 'Dnajc7', 'Oxct1',
#                                  'Mxra8', 'Mff', 'Mrpl53', 'Lonp2', 'Jkamp', 'Thumpd3', 'Idh3g', 'Tnfaip1', 'Dld',
#                                  'Prdx3', 'Etfb', 'Scfd1', 'Ift46', 'Cbr4', 'Cr1l', '4930453N24Rik', 'Cdadc1',
#                                  'Lrrc42', 'Eda2r', 'Fam107b', 'Ftsj3', 'Uros', 'Chchd1', 'Rab28', '1700123O20Rik',
#                                  'Msto1', 'Frg1', 'Pygm', 'Acadm', 'Prmt7', 'Dhx15', 'Tsc22d3', 'Igf1', 'Poglut1',
#                                  'Rhog', '1500011B03Rik', 'Cited2', 'Klhl7', 'Nadk', 'Actr1a', 'Ap3s1', 'Hspd1',
#                                  'Chn2', 'Rhoq', 'Wdr37', 'Ssr4', 'Atp6v0e2', 'Otud6b', 'Gpx7', 'Gss', 'Cuedc2',
#                                  'Ddost', 'Adsl', 'Zfyve21', 'Ppil4', 'Imp4', 'Vipar', 'Tor1b', 'Pmpca', 'Nsdhl',
#                                  'Orc4', 'Bid', 'Tomm70a', 'Dpy30', 'Mrpl10', 'Gap43', 'Cops4', 'Hars', 'Fam33a',
#                                  'Pgls', 'Ccdc101', 'Tcta', 'Wdr77', '8430410K20Rik', 'Cd47', 'Stoml2', 'Rab30',
#                                  'Fibp', 'Tmem29', 'Tmem66', 'Tpd52', 'Cog4', '1500001M20Rik', 'Cmpk1', 'Tusc3',
#                                  'Acadsb', 'Ppp2cb', 'Rnf114', 'Fam192a', 'Ncald', 'Tgfb3', 'Ccrn4l', 'Ggps1',
#                                  'Mrpl1', 'Abhd14a', 'Gnptg', 'Nqo1', 'Cdca3', 'Flot1', 'Tpm3', 'Ly96', 'Prrx1',
#                                  'Taf11', 'Arfip1', 'Cuta', 'Wdr75', 'Mbnl1', 'Copg', 'Pgm2', 'Vbp1', 'Sbds',
#                                  'Arl1', 'Mtfr1', 'Errfi1', 'Psmc4', 'Cdc16', 'Got2', 'Sar1a', 'Psmd14', 'Zfp238',
#                                  'Trap1', 'Casp6', 'Rad21', 'Tcf12', 'Exosc1', 'Ccdc58', 'Nudt8', 'Coro1c',
#                                  'Snai2', 'Fbxo11', '2610524H06Rik', 'Hdac2', 'Adprh', 'Tomm22', 'Comt', 'Lap3',
#                                  'Cstf3', 'Ddrgk1', 'Mrpl43', 'Lsm4', 'Lyrm2', 'Tmem106c', 'Pigf', 'Snhg9',
#                                  'Loxl1', '9530068E07Rik', 'Psme1', 'Cab39', '2610301B20Rik', 'D230037D09Rik',
#                                  'Mgrn1', 'Uckl1', 'Prkra', 'C330007P06Rik', 'S100a13', 'Rchy1', 'Gpm6b', 'Sdf2',
#                                  'Cinp', 'Bag1', 'Fam164a', 'Eno1', 'Arl6ip1', 'Amd2', '1110051M20Rik', 'Snx4',
#                                  'Tpp1', 'Cacna2d1', 'Sgcb', 'Tmem184c', 'Gm5506', 'Rbms1', 'Rtn3', 'Ddx52',
#                                  'Ppp2r1a', 'Gnpnat1', 'Fkbp4', 'Nucb1', 'Creld2', 'Ostc', 'Yaf2', 'Ccdc104',
#                                  'Adam9', 'Cdk1', 'Rhoj', 'Actg2', 'Acat1', 'Zfp330', 'Efnb2', 'Atic', 'Clybl',
#                                  'Rad23a', '6330578E17Rik', 'Skap2', '4921524J17Rik', 'Psmc5', 'Gpc3', 'Sqstm1',
#                                  'Cnot8', 'Abce1', 'Itgb1bp1', 'Gpc4', 'Pdgfa', 'Arhgdia', 'Chchd7', 'Metap1',
#                                  'Casp3', 'Mbnl3', 'B230118H07Rik', 'Rpn1', 'Map1lc3a', 'Snapc2', 'Zbtb8os',
#                                  'Prc1', 'Zfp672', 'Commd5', 'Cd99l2', 'Ube2g2', 'Ndrg4', 'Uqcrc1', 'Sri', 'Adss',
#                                  'Crbn', 'Mier3', 'Eif2b2', 'Kdelc1', '9130401M01Rik', 'Zfp277', '2210403K04Rik',
#                                  'Lyrm4', 'AI987944', 'Rpf1', 'Slc18a2', 'Rnf5', 'Grb10', 'Ngfrap1', 'Dctn5',
#                                  'Bag5', 'Dusp14', 'AW209491', 'Serinc2', 'Eif3j', 'Ccnh', 'Bfar', 'Gng11',
#                                  'Tmem170b', 'Chordc1', 'Sh3glb2', 'Serpine1', 'Selm', 'Maea', 'Flna', 'Zc3h14',
#                                  'Cacybp', 'Gfm1', 'Zfp62', 'Eapp', 'Zfp207', 'Stard7', 'D19Bwg1357e', 'Mrps2',
#                                  'Nip7', 'Atp6v0d1', 'Scrn1', 'Slc31a1', 'Tnfrsf1a', 'Gins4', 'Lima1', 'Kdm1b',
#                                  'Mtpap', 'Cisd1', 'Cdc123', 'Mrps34', 'Strap', 'Eif3b', 'Spc25', 'Ccnc',
#                                  '1110002N22Rik', 'Eif2d', '1700020I14Rik', 'Ckap4', 'Aimp1', 'Xbp1', 'Pfdn4',
#                                  'Mmp14', 'Alg11', 'Ptbp2', 'Aktip', 'Rpl7l1', 'Ube2w', 'Asnsd1', 'Dnm3os',
#                                  'Sep15', 'Zfp36l1', 'Lamp2', 'Wdr43', 'Crot', 'Ctsd', 'Zcchc10', 'Smcr7l',
#                                  'Pfdn2', 'Ssu72', 'Ppap2b', '2010320M18Rik', 'Taf1d', 'Ubl4', 'Sox9', 'AI597468',
#                                  'Ergic3', 'Srprb', 'Got1', 'Snupn', '2310046O06Rik', '1110034B05Rik', 'Ccdc47',
#                                  'Rrp1', 'Psmd8', 'Eps15', 'Nup93', 'Fam171b', 'Slc12a6', 'Cdipt', 'Tbce', 'Anxa6',
#                                  'Tceb3', 'Msra', 'Zfp266', 'Tram1', 'Arcn1', 'Kif20a', 'Pitrm1', 'Hnrnph1',
#                                  'Mrpl48', 'Abi2', 'B4galt1', 'Naa10', 'Ppme1', 'Tbx15', 'Fam114a2', 'Clk3',
#                                  'Acot10', 'Lamtor3', 'Wbp1', 'Cnpy2', 'Cyb5r3', '4732418C07Rik', 'Ppp2r3c',
#                                  'Coq5', 'Nat15', 'Lmcd1', 'Lgals8', 'Ptpmt1', 'Obfc2b', 'Ttc4', 'Tor1aip2',
#                                  'Fech', 'Dmtf1', 'Casc4', 'Tprgl', 'Ppil2', 'Sdha', 'Ncstn', '2610203C20Rik',
#                                  'Hn1', 'Dnajc30', 'Atg5', 'Mtap6', 'Ppfibp1', 'Bet1l', '2510006D16Rik', 'Clta',
#                                  'Gtf2f1', 'Sugt1', 'Ddx3y', 'Polr2i', 'Fbxo32', 'Idh1', 'Hspa13', 'Fez2', 'Tada1',
#                                  'Eif3i', 'Tfg', 'Glud1', '2410001C21Rik', 'Hmgn2', 'Ccdc25', 'Pdhb', 'Polr3k',
#                                  'Gng12', 'Stk17b', 'Ptgr1', 'Apoo', 'Dnajc4', 'Arf2', '3110001D03Rik', 'Mrto4',
#                                  'Mea1', 'Actr1b', 'Eif4b', 'Ociad1', 'Mapk1ip1', 'Eid1', 'Gosr2', 'Srsf1',
#                                  'Fam198b', 'Parp2', 'Mtg1', 'Cdc42ep3', 'Slc20a1', 'Nck1', 'Klhdc2',
#                                  '1110003E01Rik', 'Hbegf', 'Eif4e2', 'Hipk3', 'Vps29', 'Mkx', 'Sfxn1', 'Ccdc56',
#                                  'Gm5617', 'Avpi1', 'Trp53inp2', 'Slc38a2', 'Pigs', 'Mtap2', 'Hmgn1',
#                                  '2310040G24Rik', 'Zfp639', 'Snrpd1', 'Chchd6', 'Serpinh1', 'Golph3', 'Armc1',
#                                  'Vps36', 'Tmem159', '1810030O07Rik', 'Thoc1', 'Dhrs7b', 'Ublcp1', 'Rps27',
#                                  'Arl5a', 'Mier1', 'Atp1b3', 'Cct3', 'Ifrd1', 'Gse1', 'Ube2a', 'Pla2g4a',
#                                  'Tgfb1i1', 'Cdk5', 'Kbtbd2', 'Dpcd', 'Socs2', '3110040N11Rik', 'Impact', 'Cdc23',
#                                  'Llph', 'Pdcl', 'Nptn', 'Wdr6', 'Vcl', 'Lsg1', 'Cpsf3l', 'Cdc42se1', 'Srp68',
#                                  'Gde1', 'Stk3', 'Gnl2', 'Cct4', 'Ranbp9', 'Ccdc127', 'Tm9sf2', 'Timm17b', 'Pkp4',
#                                  'Asl', 'Slc31a2', 'D4Bwg0951e', '5730403B10Rik', 'Med7', 'Abi1', 'AK010878',
#                                  'Utp3', 'Rnps1', 'Otud1', 'Nenf', 'Btbd10', 'Aasdhppt', 'Fam58b', 'Gm2382',
#                                  'Fam32a', '1700037H04Rik', 'Tmem70', 'Puf60', 'Clip3', 'Exoc7', 'Acat2', 'Cope',
#                                  'Ppp2r3a', 'Hsph1', 'Sec23b', 'Mycbp', 'Actr3', 'Api5', 'Bphl', 'Ola1', 'Zcchc9',
#                                  'Rcn2', 'Atg10', 'Ebna1bp2', 'Orc5', 'Npc2', 'Cd82', 'Krcc1', 'Pole4', 'Pdk3',
#                                  'Fbxo25', 'Mtx1', 'Sigmar1', 'Jag1', 'Sh3gl1', 'Rbbp7', 'Tceal7', 'Slc30a6',
#                                  'Alkbh8', 'Mrps17', '4933433P14Rik', 'Rab2b', 'Ube2l6', 'Gprasp1', 'Filip1',
#                                  'Bola1', 'Nucb2', 'Clu', 'Riok2', 'Enoph1', 'Hdhd2', 'Lman1', 'Zfp868', 'Airn',
#                                  'Ccnb1', 'Commd6', 'Nmt1', 'Rnf187', 'Gmpr', 'Stx5a', 'Fkbp8', 'Htatsf1',
#                                  'Brms1l', 'Bckdk', 'Dpy19l1', 'Flot2', 'Txnl4b', 'Mrpl3', 'Mlf2', 'Gatc',
#                                  'Zc3hc1', 'Mad2l2', 'Eif1ad', 'Mrpl18', 'Ivns1abp', 'Atoh8', 'Eed', 'Fbxo22',
#                                  'P4ha1', 'App', 'Tuba4a', 'Osbpl1a', '1110065P20Rik', 'Palmd', 'Dnajc10',
#                                  'Snrpb2', 'Pstk', 'Aco2', 'Sqle', 'Ube2e2', 'Bod1', 'Ccpg1', 'Gpatch4', 'Chmp1b',
#                                  'Snx32', 'Polr2m', 'Trim35', '2310004I24Rik', 'Tcp11l2', 'Fermt2', 'Ilf3',
#                                  'Brms1', 'Tmem218', 'Cdc42se2', 'Pih1d1', 'Syt4', 'Rapgef2', 'Wsb2', 'Tbc1d15',
#                                  'Las1l', 'Plekhb2', 'Prps1', 'Fabp3', 'Mrpl22', 'Kpna3', 'Mtch1', 'Wwtr1',
#                                  'Sec23a', 'Med31', 'Bhlhb9', '4933421E11Rik', 'Tmed7', 'Imp3', 'Lrrc28', 'Vps4a',
#                                  'Pgam5', 'Inpp4a', 'Pofut2', 'Mphosph10', 'Ctgf', '8430410A17Rik', 'Ppdpf',
#                                  'Cklf', 'Ifngr1', 'Anp32b', 'Akirin2', 'Hadhb', 'Wsb1', 'Tax1bp3', 'Tob1',
#                                  'Ttc35', 'Mapk3', 'Ccdc6', 'Zcchc18', 'Cstf1', 'Ccm2', 'Phax', 'Bin3', 'Arl6',
#                                  'Stmn3', 'Fam114a1', 'Vamp7', 'Zfp422', 'Ctsa', 'Lyar', 'Pdcl3', 'Bloc1s2',
#                                  'Tmem30a', 'Hmgb3'], 'feature_info': Empty DataFrame
#                                  Columns: []
#                                  Index: [Acta1, Tnnc2, Myl1, Tnni1, Tnnc1, Pgam2, S100a6, Acta2, Tnnt2, Mylpf,
#                                  Tnnt3, Mgp, S100a4, Tagln, Spp1, Anxa1, Timp1, Cox8b, Cav1, Bgn, Arhgdib, Tagln2,
#                                  Anxa2, Fstl1, Ifitm3, Tm4sf1, Snca, Eno3, Anxa3, Itm2a, Vim, Cox6a2, Crabp1, Gja1,
#                                  Postn, Cnn2, Cdkn1c, Col1a2, Ifi27l2a, Tubb3, Fhl1, Tnfrsf12a, Itgb1bp2, Mfap2,
#                                  Atp6v0c, Rrm2, Nupr1, Serpine2, S100a11, Fos, Ogn, Ascl1, Mybpc1, 1810020D17Rik,
#                                  Tpm4, Gsto1, Ldb3, Ifitm2, Tnnt1, Serpinf1, Il1rl1, S100a10, Ndufs5, Cks1b,
#                                  Prune2, Myl9, Mfap4, D0H4S114, Ddx39, Asph, Mest, Hspb8, Kbtbd10, Emp3, rtTA, Dcn,
#                                  Pdlim3, Hmga2, Sc4mol, Enc1, Ppic, Sept4, Prss23, Prdx4, Sgk1, Egr1, Sdc4, Cd44,
#                                  Lrrc17, Crip1, Mt1, Aspn, Timm10, Emp1, Hist1h2bc, Mgst1, Aprt, Fxyd1, Stmn1,
#                                  Pmp22, ...]
#
#                                  [2000 rows x 0 columns], 'pydynwrap:data_wrapper': True, 'counts': <Compressed
#                                  Sparse Column sparse matrix of dtype 'float64'
#                                          with 502036 stored elements and shape (392, 2000)>, 'expression':
#                                  <Compressed Sparse Column sparse matrix of dtype 'float64'
#                                          with 502036 stored elements and shape (392, 2000)>, 'adata': AnnData
#                                  object with n_obs × n_vars = 392 × 2000
#                                      layers: 'counts', 'expression', 'pydynwrap:with_expression': True}
#                         INFO     Dataset loading finished

# %%
# 2. 选择方法(method), 目前stuba和grandprix有点问题
# methods_selected_list = [ti_comp1(), ti_slingshot(), ti_monocle_ddrtree(), ti_mst(), ti_scuba(), ti_angle(), ti_grandprix()]
# methods_selected_list = [ti_slingshot()]
# methods_selected = methods_selected_list[0]

# 字典方式调用，方便后续保存json文件
# 每类wrapper选择一种方法
method_type_dict = {
    # type2method
    "trajectory": {
        "name": "slingshot",  # 轨迹推断方法名称
        "function": pdv.methods.ti_slingshot,  # 轨迹方法函数名，不直接调用
    },
    "linear_trajectory": {
        "name": "comp1",
        "function": pdv.methods.ti_comp1,
    },
    "cycle": {
        "name": "angle",
        "function": pdv.methods.ti_angle,
    },
    "end_state_probabilities": {
        "name": "grandprix",
        "function": pdv.methods.ti_grandprix,
    },
    "cluster_graph": {
        "name": "scuba",
        "function": pdv.methods.ti_scuba,
    },
    "dimred_projection": {
        "name": "mst",
        "function": pdv.methods.ti_mst,
    },
    "cell_graph": {
        "name": "monocle_ddrtree",
        "function": pdv.methods.ti_monocle_ddrtree,
    },
}

method_type = "linear_trajectory" # 此处选择方法的wrapper类型
methods_selected = method_type_dict[method_type]["function"]()

logger.info(f"Methods {methods_selected} selecting finished")
# Out:
#                         INFO     backend: container
#                         DEBUG    Docker image(dynverse/ti_comp1:v0.9.9.01) loaded
#                         INFO     Methods {'method': {'id': 'comp1', 'name': 'Component 1', 'source': 'offtheshelf',
#                                  'platform': 'R'}, 'wrapper': {'type': 'linear_trajectory', 'topology_inference':
#                                  'fixed', 'trajectory_types': 'linear', 'input_required': 'expression', 'inputs':
#                                  input_id  required        type
#                                  0  expression      True  expression
#                                  1      dimred     False   parameter
#                                  2        ndim     False   parameter
#                                  3   component     False   parameter}, 'container': {'url':
#                                  'https://github.com/dynverse/ti_comp1', 'docker': 'dynverse/ti_comp1'}, 'package':
#                                  None, 'manuscript': None, 'parameters':                   id
#                                  description  \
#                                  id
#                                  dimred        dimred  Which dimensionality reduction method to use.
#                                  ndim            ndim                                            NaN
#                                  component  component                                            NaN
#
#                                                  type default  \
#                                  id
#                                  dimred     character     pca
#                                  ndim         integer       2
#                                  component    integer       1
#
#                                                                                        values  \
#                                  id
#                                  dimred     [pca, mds, tsne, ica, lle, landmark_mds, mds_s...
#                                  ndim                                                     NaN
#                                  component                                                NaN
#
#                                                                             distribution
#                                  id
#                                  dimred                                              NaN
#                                  ndim       {'type': 'uniform', 'lower': 2, 'upper': 30}
#                                  component  {'type': 'uniform', 'lower': 1, 'upper': 10}  , 'run': {'backend':
#                                  'container', 'container_id': 'dynverse/ti_comp1:v0.9.9.01'}} selecting finished

# %%
# 3. 运行方法(wrap)
# add_prior_information(dataset, end_n=3)  # 运行grandprix需要的先验知识
model = pdv.wrap.infer_trajectory(dataset, methods_selected)
logger.info(f"Methods executing finished, model: {model}")

# # 保存Docker Output输出的json文件
# import json

# method_name = method_type_dict[method_type]["name"]
# json_filename = f"output/24.11.27-quick_docker_output_json/{method_type}_{method_name}.json"
# with open(json_filename, "w") as f:
#     json.dump(model.output_json, f)
# logger.info(f"Docker output json file({json_filename}) save")
# Out:
#                         DEBUG    Temp wd: /tmp/tmptx1kt7mu
#                         DEBUG    Save json successfully, path: /tmp/tmptx1kt7mu/input.json
#                         DEBUG    h52json script:
#                                  /home/huang/PyCode/scRNA/PyDynverse/PyDynverse/pydynverse/util/../rscript/docker_i
#                                  nput_json2h5.R
# [2024年12月25日 15时38分22秒] DEBUG    CompletedProcess(args=['/home/huang/PyCode/scRNA/PyDynverse/PyDynverse/pydyn
#                                        verse/util/../rscript/docker_input_json2h5.R', '--input_json_filename',
#                                        '/tmp/tmptx1kt7mu/input.json', '--input_h5_filename',
#                                        '/tmp/tmptx1kt7mu/input.h5'], returncode=0, stdout='[1] "json2h5
#                                        successful!"\n', stderr='')
#                         DEBUG    json2h5 successful!
#                         DEBUG    docker args: ['--dataset', '/ti/input.h5', '--output', '/ti/output.h5']
# [2024年12月25日 15时38分25秒] DEBUG    Docker Finish
#                         DEBUG
#                         DEBUG    h52json script:
#                                  /home/huang/PyCode/scRNA/PyDynverse/PyDynverse/pydynverse/util/../rscript/docker_o
#                                  utput_h52json.R
# [2024年12月25日 15时38分26秒] DEBUG    CompletedProcess(args=['/home/huang/PyCode/scRNA/PyDynverse/PyDynverse/pydyn
#                                        verse/util/../rscript/docker_output_h52json.R', '--output_h5_filename',
#                                        '/tmp/tmptx1kt7mu/output.h5', '--output_json_filename',
#                                        '/tmp/tmptx1kt7mu/output.json'], returncode=0, stdout='[1] "h52json
#                                        successful!"\n', stderr='')
#                         DEBUG    h52json successful!
#                         DEBUG    Save json successfully, path: /tmp/tmptx1kt7mu/output.json
#                         INFO     Methods executing finished, model:
#                                              id: ['20241225_073824__data_wrapper__bGKqycDhTP'],
#                                              trajectory_type: ['linear'],
#                                              attribute_list: dict_keys(['id', 'pseudotime', 'output_h5_filename',
#                                  'output_json_filename', 'cell_ids', 'cell_info', 'milestone_ids',
#                                  'milestone_network', 'divergence_regions', 'milestone_percentages',
#                                  'progressions', 'trajectory_type', 'directed', 'dimred', 'dimred_projected',
#                                  'dimred_milestones', 'dimred_segment_progressions', 'dimred_segment_points',
#                                  'timings', 'output_json', 'adata'])

# %%
# 4. 绘制轨迹(dimred+plot)
# model = add_dimred(model, dimred_mds,  expression_source=dataset["expression"])  # 提取降维结果, 直接从docker输出容器获得
pdv.plot.plot_dimred(model, expression_source=dataset["expression"], grouping=list(fibroblast_reprogramming_treutlein["grouping"]))
logger.info("Result plotting finished")
# Out:
#                         INFO     Coloring by grouping
# WARNING: The following color value found in adata.uns['grouping_colors'] is not valid: 'Neuron'. Default colors will be used instead.
#                         DEBUG    selecting waypoints
# [2024年12月25日 15时38分36秒] DEBUG    selecting waypoints shape is (201, 392), finished!
#                         INFO     Result plotting finished
