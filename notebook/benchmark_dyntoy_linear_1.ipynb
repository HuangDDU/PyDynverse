# %%
import pydynverse as pdv

logger = pdv.logger
logger.setLevel("DEBUG")
# Out:
#   _____       _____
#  |  __ \     |  __ \
#  | |__) |   _| |  | |_   _ _ ____   _____ _ __ ___  ___
#  |  ___/ | | | |  | | | | | '_ \ \ / / _ \ '__/ __|/ _ \
#  | |   | |_| | |__| | |_| | | | \ V /  __/ |  \__ \  __/
#  |_|    \__, |_____/ \__, |_| |_|\_/ \___|_|  |___/\___|
#          __/ |        __/ |
#         |___/        |___/

# %%
# 1. 准备数据(wrap)
dataset = pdv.data.load_simulation_data("synthetic/dyntoy/linear_1.rds")
# 直接可视化轨迹
dataset
# Out:
# {'id': 'synthetic/dyntoy/linear_1',
#  'cell_ids': ['C1',
#   'C2',
#   'C3',
#   'C4',
#   'C5',
#   'C6',
#   'C7',
#   'C8',
#   'C9',
#   'C10',
#   'C11',
#   'C12',
#   'C13',
#   'C14',
#   'C15',
#   'C16',
#   'C17',
#   'C18',
#   'C19',
#   'C20',
#   'C21',
#   'C22',
#   'C23',
#   'C24',
#   'C25',
#   'C26',
#   'C27',
#   'C28',
#   'C29',
#   'C30',
#   'C31',
#   'C32',
#   'C33',
#   'C34',
#   'C35',
#   'C36',
#   'C37',
#   'C38',
#   'C39',
#   'C40',
#   'C41',
#   'C42',
#   'C43',
#   'C44',
#   'C45',
#   'C46',
#   'C47',
#   'C48',
#   'C49',
#   'C50',
#   'C51',
#   'C52',
#   'C53',
#   'C54',
#   'C55',
#   'C56',
#   'C57',
#   'C58',
#   'C59',
#   'C60',
#   'C61',
#   'C62',
#   'C63',
#   'C64',
#   'C65',
#   'C66',
#   'C67',
#   'C68',
#   'C69',
#   'C70',
#   'C71',
#   'C72',
#   'C73',
#   'C74',
#   'C75',
#   'C76',
#   'C77',
#   'C78',
#   'C79',
#   'C80',
#   'C81',
#   'C82',
#   'C83',
#   'C84',
#   'C85',
#   'C86',
#   'C87',
# ...

# %%
dataset["milestone_network"]
# Out:
#   from  to    length  directed
# 1   M1  M2  0.709515      True
# 2   M2  M3  0.043620      True
# 3   M3  M4  0.123677      True
# 4   M4  M5  0.625598      True

# %%
pdv.plot.plot_graph(dataset)

# %%
pdv.plot.plot_dimred(dataset)
# Out:
# [2025年01月08日 19时12分58秒] INFO     Coloring by milestone
#                         DEBUG    selecting waypoints
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pdv.plot.plot_dimred(dataset)
#
# File ~/PyCode/scRNA/PyDynverse/PyDynverse/pydynverse/plot/plot_dimred.py:110, in plot_dimred(trajectory, color_cells, dimred, plot_trajectory, plot_milestone_network, size_milestones, size_transitions, grouping, feature_oi, color_milestones, groups, milestones, milestone_percentages, pseudotime, expression_source, arrow, waypoints, trajectory_projection_sd, color_trajectory)
#     103     # # TODO: 需要了解WayPoint概念,真正的投影
#     104     # milestone_positions = edge_positions[edge_positions["percentage"] == 0]
#     105     # ax.scatter(edge_positions[0], edge_positions[1], c="black", s=size_transitions)
# ...
